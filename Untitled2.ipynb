# %%
import pandas as pd
import numpy as np
from datetime import datetime, date, time
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Historic Index Data.csv")

# %%
# Convert relevant columns to numeric types
numeric_columns = ['Open', 'High', 'Low', 'Close', 'Turnover']
for column in numeric_columns:
    data[column] = pd.to_numeric(data[column].str.replace(',', ''), errors='coerce')

# %%
# Convert the 'Date' column to datetime type
data['Date'] = pd.to_datetime(data['Date'], format='%d/%m/%Y')

# %%
# Drop the 'S.N.' column if it exists
if 'S.N.' in data.columns:
    data = data.drop('S.N.', axis=1)

# %%
# Reverse the data to go from past to future dates
data = data.iloc[::-1]

# %%
# Set the 'Date' column as the index
data.set_index('Date', inplace=True)

# %%
def calculate_atr(data, window):
    data['Previous Close'] = data['Close'].shift(1)
    data['TR'] = data[['High', 'Low', 'Previous Close']].apply(lambda x: max(x['High'] - x['Low'], abs(x['High'] - x['Previous Close']), abs(x['Previous Close'] - x['Low'])), axis=1)
    atr = data['TR'].rolling(window=window).mean()
    data.drop(['Previous Close', 'TR'], axis=1, inplace=True)  # Clean up intermediate columns
    return atr

# %%
# Calculate RSI
def calculate_rsi(data, window):
    delta = data['Close'].diff(1)
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

# %%
# Calculate Moving Average (MA)
def calculate_ma(data, window):
    return data['Close'].rolling(window=window).mean()

# %%
# Calculate Exponential Moving Average (EMA)
def calculate_ema(data, span):
    return data['Close'].ewm(span=span, adjust=False).mean()

# %%
# Calculate MACD
def calculate_macd(data, short_window, long_window):
    short_ema = calculate_ema(data, short_window)
    long_ema = calculate_ema(data, long_window)
    macd = long_ema - short_ema 
    return macd

# %%
# Define windows for calculations
rsi_window = 14
ma_window = 14
atr_window = 14
short_ema_window = 12
long_ema_window = 26
mfi_window = 14

# %%
# Add calculated indicators to the DataFrame
data['RSI'] = calculate_rsi(data, rsi_window)
data['MA'] = calculate_ma(data, ma_window)
data['12-day EMA'] = calculate_ema(data, short_ema_window)
data['26-day EMA'] = calculate_ema(data, long_ema_window)
data['MACD'] = calculate_macd(data, short_ema_window, long_ema_window)
data['ATR'] = calculate_atr(data,atr_window)

# %%
data.loc['2016-07-21']
# Out:
# Open              1.786840e+03
# High              1.804750e+03
# Low               1.779710e+03
# Close             1.798830e+03
# Change            1.199000e+01
# Per Change (%)    6.700000e-01
# Turnover          1.429860e+09
# RSI               7.016430e+01
# MA                1.736406e+03
# 12-day EMA        1.749282e+03
# 26-day EMA        1.702396e+03
# MACD             -4.688594e+01
# ATR               2.619857e+01
# Name: 2016-07-21 00:00:00, dtype: float64

# %%
macro_economics  = pd.read_csv("./Macro_Economic.csv", index_col = 'Date')
macro_economics.index = pd.to_datetime(macro_economics.index, format = '%Y-%m').to_period('M')
macro_economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 108 entries, 2015-07 to 2024-06
# Freq: M
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Inflation Rate(%)        106 non-null    float64
#  1   Remittance (in Billons)  94 non-null     float64
#  2   Treasury Bill            96 non-null     float64
#  3   Commercial Bank rates    96 non-null     float64
#  4   CPI                      100 non-null    float64
#  5   Exchange Rate            102 non-null    float64
# dtypes: float64(6)
# memory usage: 5.9 KB

# %%
macro_economics["Year"] = macro_economics.index.year
macro_economics["Month"] = macro_economics.index.month
macro_economics.head()
# Out:
#          Inflation Rate(%)  Remittance (in Billons)  Treasury Bill  \
# Date
# 2015-07                6.9                      NaN            NaN
# 2015-08                7.2                      NaN            NaN
# 2015-09                8.2                      NaN            NaN
# 2015-10               10.4                      NaN            NaN
# 2015-11               11.6                      NaN            NaN
#
#          Commercial Bank rates  CPI  Exchange Rate  Year  Month
# Date
# 2015-07                    NaN  NaN            NaN  2015      7
# 2015-08                    NaN  NaN            NaN  2015      8
# 2015-09                    NaN  NaN            NaN  2015      9
# 2015-10                    NaN  NaN            NaN  2015     10
# 2015-11                    NaN  NaN            NaN  2015     11

# %%
data['Year'] = data.index.year
data['Month'] = data.index.month
data.head()
# Out:
#                Open     High      Low    Close  Change  Per Change (%)  \
# Date
# 2016-01-04  1154.62  1154.62  1154.62  1154.62   -6.22           -0.54
# 2016-01-05  1146.11  1146.11  1146.11  1146.11   -7.85           -0.68
# 2016-01-06  1149.89  1149.89  1149.89  1149.89    3.12            0.27
# 2016-01-07  1164.14  1164.14  1164.14  1164.14   14.25            1.24
# 2016-01-10  1167.18  1167.18  1167.18  1167.18    3.04            0.26
#
#             Turnover  RSI  MA   12-day EMA   26-day EMA      MACD  ATR  Year  \
# Date
# 2016-01-04       0.0  NaN NaN  1154.620000  1154.620000  0.000000  NaN  2016
# 2016-01-05       0.0  NaN NaN  1153.310769  1153.989630  0.678860  NaN  2016
# 2016-01-06       0.0  NaN NaN  1152.784497  1153.685953  0.901456  NaN  2016
# 2016-01-07       0.0  NaN NaN  1154.531497  1154.460327 -0.071170  NaN  2016
# 2016-01-10       0.0  NaN NaN  1156.477421  1155.402525 -1.074896  NaN  2016
#
#             Month
# Date
# 2016-01-04      1
# 2016-01-05      1
# 2016-01-06      1
# 2016-01-07      1
# 2016-01-10      1

# %%
merged_data = pd.merge(data, macro_economics, on = ['Year', 'Month'], how = 'left')
merged_data.index = data.index

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1928 entries, 2016-01-04 to 2024-05-16
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Open                     1928 non-null   float64
#  1   High                     1928 non-null   float64
#  2   Low                      1928 non-null   float64
#  3   Close                    1928 non-null   float64
#  4   Change                   1928 non-null   float64
#  5   Per Change (%)           1928 non-null   float64
#  6   Turnover                 1928 non-null   float64
#  7   RSI                      1915 non-null   float64
#  8   MA                       1915 non-null   float64
#  9   12-day EMA               1928 non-null   float64
#  10  26-day EMA               1928 non-null   float64
#  11  MACD                     1928 non-null   float64
#  12  ATR                      1915 non-null   float64
#  13  Year                     1928 non-null   int32
#  14  Month                    1928 non-null   int32
#  15  Inflation Rate(%)        1917 non-null   float64
#  16  Remittance (in Billons)  1797 non-null   float64
#  17  Treasury Bill            1841 non-null   float64
#  18  Commercial Bank rates    1841 non-null   float64
#  19  CPI                      1917 non-null   float64
#  20  Exchange Rate            1928 non-null   float64
# dtypes: float64(19), int32(2)
# memory usage: 380.9 KB

# %%
merged_data[merged_data['CPI'].isnull()]
# Out:
#                Open     High      Low    Close  Change  Per Change (%)  \
# Date
# 2024-05-02  2025.78  2025.78  1995.84  1998.96   -7.31           -0.36
# 2024-05-05  1998.44  1998.52  1970.23  1974.37  -24.58           -1.23
# 2024-05-06  1980.22  1980.22  1952.96  1958.75  -15.62           -0.79
# 2024-05-07  1959.91  1970.44  1955.22  1960.81    2.06            0.10
# 2024-05-08  1961.27  1967.92  1954.39  1960.60   -0.21           -0.01
# 2024-05-09  1963.45  1970.35  1955.27  1966.23    5.63            0.28
# 2024-05-12  1973.78  1981.57  1962.21  1974.50    8.26            0.42
# 2024-05-13  1979.68  2000.14  1970.64  1998.89   24.39            1.23
# 2024-05-14  2000.66  2027.51  1999.56  2027.51   28.62            1.43
# 2024-05-15  2030.87  2048.23  2013.53  2017.97   -9.54           -0.47
# 2024-05-16  2029.10  2029.10  2009.56  2018.76    0.79            0.03
#
#                 Turnover        RSI           MA   12-day EMA  ...       MACD  \
# Date                                                           ...
# 2024-05-02  4.133363e+09  40.828558  1993.530714  1992.415266  ...  13.360963
# 2024-05-05  3.795748e+09  31.569190  1989.127857  1989.639071  ...  13.810770
# 2024-05-06  2.891320e+09  30.668681  1984.374286  1984.886906  ...  15.251836
# 2024-05-07  2.140503e+09  31.845100  1979.907143  1981.182767  ...  16.042735
# 2024-05-08  2.547031e+09  35.246112  1976.627143  1978.016187  ...  16.496314
# 2024-05-09  3.121286e+09  41.300191  1974.807143  1976.202928  ...  16.214574
# 2024-05-12  3.155142e+09  50.873169  1974.975714  1975.940939  ...  15.149340
# 2024-05-13  3.408608e+09  54.910350  1976.008571  1979.471564  ...  12.196473
# 2024-05-14  4.088854e+09  68.226862  1980.186429  1986.862092  ...   7.460904
# 2024-05-15  3.708430e+09  64.366463  1983.672143  1991.647924  ...   4.426702
# 2024-05-16  4.233816e+09  65.780513  1987.445714  1995.819013  ...   1.936012
#
#                   ATR  Year  Month  Inflation Rate(%)  \
# Date
# 2024-05-02  22.552143  2024      5                NaN
# 2024-05-05  23.250000  2024      5                NaN
# 2024-05-06  23.165000  2024      5                NaN
# 2024-05-07  23.277143  2024      5                NaN
# 2024-05-08  22.506429  2024      5                NaN
# 2024-05-09  22.293571  2024      5                NaN
# 2024-05-12  21.896429  2024      5                NaN
# 2024-05-13  21.785000  2024      5                NaN
# 2024-05-14  21.832857  2024      5                NaN
# 2024-05-15  23.165714  2024      5                NaN
# 2024-05-16  23.585714  2024      5                NaN
#
#             Remittance (in Billons)  Treasury Bill  Commercial Bank rates  \
# Date
# 2024-05-02                      NaN            NaN                    NaN
# 2024-05-05                      NaN            NaN                    NaN
# 2024-05-06                      NaN            NaN                    NaN
# 2024-05-07                      NaN            NaN                    NaN
# 2024-05-08                      NaN            NaN                    NaN
# 2024-05-09                      NaN            NaN                    NaN
# 2024-05-12                      NaN            NaN                    NaN
# 2024-05-13                      NaN            NaN                    NaN
# 2024-05-14                      NaN            NaN                    NaN
# 2024-05-15                      NaN            NaN                    NaN
# 2024-05-16                      NaN            NaN                    NaN
#
#             CPI  Exchange Rate
# Date
# 2024-05-02  NaN         133.54
# 2024-05-05  NaN         133.54
# 2024-05-06  NaN         133.54
# 2024-05-07  NaN         133.54
# 2024-05-08  NaN         133.54
# 2024-05-09  NaN         133.54
# 2024-05-12  NaN         133.54
# 2024-05-13  NaN         133.54
# 2024-05-14  NaN         133.54
# 2024-05-15  NaN         133.54
# 2024-05-16  NaN         133.54
#
# [11 rows x 21 columns]

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(data['Close'], model='multiplicative',period = 90)
fig = plt.figure()
fig = decomposition.plot()
fig.set_size_inches(20,7)
plt.show()

# %%
merged_data['Trend'] = decomposition.trend
merged_data['Seasonality'] = decomposition.seasonal
merged_data['Residue'] = decomposition.resid
merged_data['Target'] = merged_data['Close'].shift(-1)

# %%
merged_data_1 = merged_data.dropna().copy()
merged_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1763 entries, 2016-07-03 to 2024-03-05
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Open                     1763 non-null   float64
#  1   High                     1763 non-null   float64
#  2   Low                      1763 non-null   float64
#  3   Close                    1763 non-null   float64
#  4   Change                   1763 non-null   float64
#  5   Per Change (%)           1763 non-null   float64
#  6   Turnover                 1763 non-null   float64
#  7   RSI                      1763 non-null   float64
#  8   MA                       1763 non-null   float64
#  9   12-day EMA               1763 non-null   float64
#  10  26-day EMA               1763 non-null   float64
#  11  MACD                     1763 non-null   float64
#  12  ATR                      1763 non-null   float64
#  13  Year                     1763 non-null   int32
#  14  Month                    1763 non-null   int32
#  15  Inflation Rate(%)        1763 non-null   float64
#  16  Remittance (in Billons)  1763 non-null   float64
#  17  Treasury Bill            1763 non-null   float64
#  18  Commercial Bank rates    1763 non-null   float64
#  19  CPI                      1763 non-null   float64
#  20  Exchange Rate            1763 non-null   float64
#  21  Trend                    1763 non-null   float64
#  22  Seasonality              1763 non-null   float64
#  23  Residue                  1763 non-null   float64
#  24  Target                   1763 non-null   float64
# dtypes: float64(23), int32(2)
# memory usage: 344.3 KB

# %%
merged_data_1.head()
# Out:
#                Open     High      Low    Close  Change  Per Change (%)  \
# Date
# 2016-07-03  1723.23  1725.47  1709.34  1719.20   -4.03           -0.23
# 2016-07-04  1723.23  1724.02  1714.84  1716.83   -2.37           -0.14
# 2016-07-05  1716.83  1717.95  1705.06  1713.03   -3.80           -0.22
# 2016-07-06  1713.03  1723.34  1712.94  1715.72    2.69            0.16
# 2016-07-10  1715.77  1732.22  1715.77  1722.53    6.81            0.40
#
#                 Turnover        RSI           MA   12-day EMA  ...  \
# Date                                                           ...
# 2016-07-03  1.720080e+09  85.115653  1667.549286  1679.865571  ...
# 2016-07-04  1.423340e+09  83.363660  1674.883571  1685.552406  ...
# 2016-07-05  1.160760e+09  80.576110  1681.495000  1689.779728  ...
# 2016-07-06  1.173100e+09  79.234355  1687.407857  1693.770539  ...
# 2016-07-10  1.324670e+09  86.399942  1694.569286  1698.195072  ...
#
#             Inflation Rate(%)  Remittance (in Billons)  Treasury Bill  \
# Date
# 2016-07-03                8.6                    51.94           0.05
# 2016-07-04                8.6                    51.94           0.05
# 2016-07-05                8.6                    51.94           0.05
# 2016-07-06                8.6                    51.94           0.05
# 2016-07-10                8.6                    51.94           0.05
#
#             Commercial Bank rates     CPI  Exchange Rate        Trend  \
# Date
# 2016-07-03                   0.69  112.88          107.5  1662.749889
# 2016-07-04                   0.69  112.88          107.5  1666.641444
# 2016-07-05                   0.69  112.88          107.5  1670.469667
# 2016-07-06                   0.69  112.88          107.5  1674.324111
# 2016-07-10                   0.69  112.88          107.5  1678.148611
#
#             Seasonality   Residue   Target
# Date
# 2016-07-03     1.009803  1.023913  1716.83
# 2016-07-04     1.013691  1.016201  1713.03
# 2016-07-05     1.013617  1.011702  1715.72
# 2016-07-06     1.010411  1.014166  1722.53
# 2016-07-10     1.002466  1.023922  1702.27
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model1 = LinearRegression()

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors],train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index = test.index, name = "Predictions")
    combined = pd.concat([test["Target"], preds], axis = 1)
    return combined

# %%
def backtest(data, model, predictors, start=600, step=200):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i]
        test = data.iloc[i:(i+step)]
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    
    return pd.concat(all_predictions)

# %%
predictors = ['Open', 'High', 'Low', 'Turnover', 'RSI', 'MA', 
              'MACD', 'ATR', 'Inflation Rate(%)', 'Remittance (in Billons)', 'Treasury Bill',
              'Commercial Bank rates', 'CPI', 'Exchange Rate','Close', 'Trend', 'Seasonality']

# %%
from sklearn.preprocessing import MinMaxScaler

feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()
merged_data_scaled = feature_scaler.fit_transform(merged_data_1[predictors])
merged_data_scaled = pd.DataFrame(merged_data_scaled, columns = predictors, index = merged_data_1.index)
merged_data_scaled["Target"] = target_scaler.fit_transform(merged_data_1[['Target']])
merged_data_scaled.head(20)
# Out:
#                 Open      High       Low  Turnover       RSI        MA  \
# Date
# 2016-07-03  0.295258  0.292544  0.293509  0.079305  0.851322  0.274106
# 2016-07-04  0.295258  0.291861  0.296154  0.065594  0.833133  0.277707
# 2016-07-05  0.292221  0.289001  0.291451  0.053463  0.804195  0.280954
# 2016-07-06  0.290418  0.291540  0.295240  0.054033  0.790266  0.283857
# 2016-07-10  0.291718  0.295724  0.296601  0.061036  0.864654  0.287374
# 2016-07-11  0.294926  0.293439  0.289951  0.039562  0.786801  0.290431
# 2016-07-12  0.285313  0.285010  0.266908  0.050346  0.714766  0.292685
# 2016-07-13  0.280948  0.278926  0.275097  0.046907  0.657830  0.294191
# 2016-07-14  0.279695  0.292327  0.283978  0.062513  0.680184  0.296010
# 2016-07-17  0.293972  0.304083  0.296288  0.059227  0.699363  0.298134
# 2016-07-18  0.305939  0.321385  0.311012  0.084816  0.707886  0.300407
# 2016-07-19  0.325311  0.333985  0.330049  0.096915  0.728794  0.303082
# 2016-07-20  0.331907  0.333995  0.328722  0.094906  0.669502  0.305266
# 2016-07-21  0.325440  0.329900  0.327347  0.065896  0.696106  0.307917
# 2016-07-25  0.331129  0.345845  0.336541  0.099572  0.764328  0.312102
# 2016-07-26  0.349946  0.360212  0.355361  0.100445  0.799116  0.317351
# 2016-07-27  0.363237  0.369296  0.368965  0.100497  0.823165  0.323259
# 2016-07-28  0.370330  0.369131  0.367551  0.097166  0.809730  0.328948
# 2016-07-31  0.368660  0.364424  0.366498  0.079080  0.757294  0.333867
# 2016-08-01  0.361600  0.359180  0.352303  0.068970  0.765926  0.338887
#
#                 MACD       ATR  Inflation Rate(%)  Remittance (in Billons)  \
# Date
# 2016-07-03  0.262844  0.136767           0.993691                 0.000000
# 2016-07-04  0.267832  0.140611           0.993691                 0.000000
# 2016-07-05  0.275955  0.146077           0.993691                 0.000000
# 2016-07-06  0.284045  0.144355           0.993691                 0.000000
# 2016-07-10  0.290494  0.141643           0.993691                 0.000000
# 2016-07-11  0.305588  0.149171           0.993691                 0.000000
# 2016-07-12  0.323194  0.183813           0.993691                 0.000000
# 2016-07-13  0.340145  0.185867           0.993691                 0.000000
# 2016-07-14  0.345170  0.196092           0.993691                 0.000000
# 2016-07-17  0.340842  0.205767           0.993691                 0.000000
# 2016-07-18  0.324343  0.209377           0.993691                 0.000000
# 2016-07-19  0.308447  0.214777           0.993691                 0.000000
# 2016-07-20  0.303380  0.230941           0.993691                 0.000000
# 2016-07-21  0.297385  0.229685           0.993691                 0.000000
# 2016-07-25  0.280508  0.249343           0.993691                 0.000000
# 2016-07-26  0.259602  0.267587           0.993691                 0.000000
# 2016-07-27  0.240603  0.275249           0.993691                 0.000000
# 2016-07-28  0.230142  0.287137           0.993691                 0.000000
# 2016-07-31  0.230793  0.287461           0.993691                 0.000000
# 2016-08-01  0.240948  0.295656           0.883281                 0.053739
#
#             Treasury Bill  Commercial Bank rates       CPI  Exchange Rate  \
# Date
# 2016-07-03       0.000000               0.079009  0.000000       0.181962
# 2016-07-04       0.000000               0.079009  0.000000       0.181962
# 2016-07-05       0.000000               0.079009  0.000000       0.181962
# 2016-07-06       0.000000               0.079009  0.000000       0.181962
# 2016-07-10       0.000000               0.079009  0.000000       0.181962
# 2016-07-11       0.000000               0.079009  0.000000       0.181962
# 2016-07-12       0.000000               0.079009  0.000000       0.181962
# 2016-07-13       0.000000               0.079009  0.000000       0.181962
# 2016-07-14       0.000000               0.079009  0.000000       0.181962
# 2016-07-17       0.000000               0.079009  0.000000       0.181962
# 2016-07-18       0.000000               0.079009  0.000000       0.181962
# 2016-07-19       0.000000               0.079009  0.000000       0.181962
# 2016-07-20       0.000000               0.079009  0.000000       0.181962
# 2016-07-21       0.000000               0.079009  0.000000       0.181962
# 2016-07-25       0.000000               0.079009  0.000000       0.181962
# 2016-07-26       0.000000               0.079009  0.000000       0.181962
# 2016-07-27       0.000000               0.079009  0.000000       0.181962
# 2016-07-28       0.000000               0.079009  0.000000       0.181962
# 2016-07-31       0.000000               0.079009  0.000000       0.181962
# 2016-08-01       0.035978               0.094340  0.051715       0.177547
#
#                Close     Trend  Seasonality    Target
# Date
# 2016-07-03  0.294859  0.286351     0.842668  0.293729
# 2016-07-04  0.293729  0.288531     0.977610  0.291918
# 2016-07-05  0.291918  0.290675     0.975041  0.293200
# 2016-07-06  0.293200  0.292833     0.863778  0.296446
# 2016-07-10  0.296446  0.294975     0.588009  0.286789
# 2016-07-11  0.286789  0.297013     0.501831  0.282404
# 2016-07-12  0.282404  0.298911     0.490518  0.281146
# 2016-07-13  0.281146  0.300713     0.372768  0.294358
# 2016-07-14  0.294358  0.302369     0.323969  0.307509
# 2016-07-17  0.307509  0.304001     0.393026  0.326970
# 2016-07-18  0.326970  0.305717     0.298808  0.333595
# 2016-07-19  0.333595  0.307452     0.384634  0.327099
# 2016-07-20  0.327099  0.309168     0.391550  0.332814
# 2016-07-21  0.332814  0.310839     0.324783  0.351717
# 2016-07-25  0.351717  0.312545     0.188832  0.365068
# 2016-07-26  0.365068  0.314319     0.246076  0.372194
# 2016-07-27  0.372194  0.316097     0.286546  0.370516
# 2016-07-28  0.370516  0.317833     0.203333  0.363285
# 2016-07-31  0.363285  0.319559     0.120050  0.355016
# 2016-08-01  0.355016  0.321264     0.109114  0.345988

# %%
preds = backtest(merged_data_scaled, model1, predictors)
preds[['Target','Predictions']] = target_scaler.inverse_transform(preds[['Target', 'Predictions']])

preds
# Out:
#              Target  Predictions
# Date
# 2019-01-28  1160.99  1161.482048
# 2019-01-29  1160.59  1156.401248
# 2019-01-30  1161.63  1156.107702
# 2019-01-31  1153.06  1157.324593
# 2019-02-03  1144.27  1144.979619
# ...             ...          ...
# 2024-02-28  1972.09  1991.964751
# 2024-02-29  1960.30  1959.742377
# 2024-03-03  2078.00  1954.057825
# 2024-03-04  2007.69  2065.879572
# 2024-03-05  2017.03  1983.668768
#
# [1163 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse = mean_squared_error(preds['Target'], preds['Predictions'])
rmse = sqrt(mse)

# %%
rmse
# Out:
# 30.757118328808026

# %%
sorted(zip(model1.coef_, predictors), reverse = True)
# Out:
# [(1.3083038831146145, 'Close'),
#  (0.15575966090890414, 'Open'),
#  (0.11049016371281717, 'Trend'),
#  (0.00906173775402161, 'Turnover'),
#  (0.005322600131768033, 'Treasury Bill'),
#  (0.0037178991521298528, 'Inflation Rate(%)'),
#  (0.003104711470500875, 'RSI'),
#  (-0.0012392236581256217, 'ATR'),
#  (-0.0014115529890449641, 'Remittance (in Billons)'),
#  (-0.002048185504947715, 'Seasonality'),
#  (-0.0023122671159389267, 'Exchange Rate'),
#  (-0.002491612886695706, 'Commercial Bank rates'),
#  (-0.004310971739402513, 'CPI'),
#  (-0.01580034966667427, 'MACD'),
#  (-0.02323413031271153, 'MA'),
#  (-0.21136944158539933, 'Low'),
#  (-0.35796659586391616, 'High')]

# %%
preds.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Without Backtesting

# %%
X_train = merged_data_scaled[predictors][:1400]
y_train = merged_data_scaled['Target'][:1400]
X_test = merged_data_scaled[predictors][1400:]
y_test = merged_data_scaled['Target'][1400:]
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1400, 17), (363, 17), (1400,), (363,))

# %%
model1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
preds_no_back_testing = model1.predict(X_test)
y_test = y_test[y_test.isnull() == False]

# %%
mse = mean_squared_error(y_test, preds_no_back_testing)
mse
# Out:
# 0.00014550871636159976

# %%
preds_no_back_testing = pd.Series(preds_no_back_testing , index = X_test.index, name = 'Predictions')
result = pd.concat([y_test, preds_no_back_testing ], axis = 1)
result.head()
# Out:
#               Target  Predictions
# Date
# 2022-08-07  0.479295     0.484352
# 2022-08-08  0.458632     0.473137
# 2022-08-09  0.455811     0.452791
# 2022-08-10  0.446774     0.452416
# 2022-08-11  0.433471     0.440163

# %%
result.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
model_random_forest = RandomForestRegressor(n_estimators = 200, min_samples_split = 50, random_state = 47)

# %%
preds_rf = backtest( merged_data_scaled,model_random_forest, predictors)
preds_rf = preds_rf.dropna()

# %%
mse_1 = mean_squared_error(preds_rf['Target'], preds_rf['Predictions'])
mse_1
# Out:
# 0.023120623307200654

# %%
preds_rf.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
def create_sequences(data, window_size=5):
    sequences = []
    targets = []
    for i in range(len(data) - window_size):
        sequences.append(data.iloc[i:i + window_size, :-1].values)  # Exclude last column (Target) for X
        targets.append(data.iloc[i + window_size, -1])  # Last column (Target) for y
    return np.array(sequences), np.array(targets)

# %%
window_size = 5
lstm_data_scaled = feature_scaler.fit_transform(merged_data_1[predictors])
target_scaled = target_scaler.fit_transform(merged_data_1[['Target']])
lstm_data = np.concatenate((lstm_data_scaled, target_scaled), axis=1)

# %%
X, y = create_sequences(pd.DataFrame(lstm_data, columns = predictors + ['Target']), window_size)

# %%
train_size = int(0.7 * len(X))
val_size = int(0.1 * len(X))
test_size = len(X) - train_size - val_size

X_train, X_val, X_test = X[:train_size], X[train_size:train_size + val_size], X[train_size + val_size:]
y_train, y_val, y_test = y[:train_size], y[train_size:train_size + val_size], y[train_size + val_size:]
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((1230, 5, 17), (1230,), (175, 5, 17), (175,), (353, 5, 17), (353,))

# %%
model = Sequential()
model.add(Input(shape = (window_size, X_train.shape[2])))
model.add(LSTM(30))
model.add(Dense(1, activation = "linear"))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 30)             │         5,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,791 (22.62 KB)
#  Trainable params: 5,791 (22.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer = Adam(learning_rate = 0.1), loss = MeanSquaredError(), metrics = [RootMeanSquaredError()])

# %%
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.7003 - root_mean_squared_error: 0.7407 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0471
# Epoch 2/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - loss: 7.6023e-04 - root_mean_squared_error: 0.0275 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0335
# Epoch 3/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - loss: 5.2628e-04 - root_mean_squared_error: 0.0229 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0341
# Epoch 4/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7322e-04 - root_mean_squared_error: 0.0217 - val_loss: 9.4637e-04 - val_root_mean_squared_error: 0.0308
# Epoch 5/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 5.3519e-04 - root_mean_squared_error: 0.0231 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0336
# Epoch 6/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 3.8401e-04 - root_mean_squared_error: 0.0195 - val_loss: 8.6316e-04 - val_root_mean_squared_error: 0.0294
# Epoch 7/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 4.4084e-04 - root_mean_squared_error: 0.0210 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0358
# Epoch 8/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 5.5881e-04 - root_mean_squared_error: 0.0235 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0515
# Epoch 9/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - loss: 6.7725e-04 - root_mean_squared_error: 0.0260 - val_loss: 9.1571e-04 - val_root_mean_squared_error: 0.0303
# Epoch 10/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 4.3020e-04 - root_mean_squared_error: 0.0207 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0352
# Epoch 11/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 5.1628e-04 - root_mean_squared_error: 0.0227 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0512
# Epoch 12/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 7.7480e-04 - root_mean_squared_error: 0.0276 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0371
# Epoch 13/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8086e-04 - root_mean_squared_error: 0.0195 - val_loss: 9.7121e-04 - val_root_mean_squared_error: 0.0312
# Epoch 14/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7419e-04 - root_mean_squared_error: 0.0193 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0335
# Epoch 15/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - loss: 5.1102e-04 - root_mean_squared_error: 0.0225 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0362
# Epoch 16/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 4.5886e-04 - root_mean_squared_error: 0.0213 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0375
# Epoch 17/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 4.1577e-04 - root_mean_squared_error: 0.0203 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0421
# Epoch 18/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 5.1740e-04 - root_mean_squared_error: 0.0227 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0545
# Epoch 19/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 4.4106e-04 - root_mean_squared_error: 0.0210 - val_loss: 9.3126e-04 - val_root_mean_squared_error: 0.0305
# Epoch 20/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 7.5032e-04 - root_mean_squared_error: 0.0273 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0331
# Epoch 21/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 4.6023e-04 - root_mean_squared_error: 0.0214 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0615
# Epoch 22/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.6869e-04 - root_mean_squared_error: 0.0216 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 23/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 6.2916e-04 - root_mean_squared_error: 0.0249 - val_loss: 8.9222e-04 - val_root_mean_squared_error: 0.0299
# Epoch 24/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - loss: 4.7917e-04 - root_mean_squared_error: 0.0217 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0671
# Epoch 25/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0693
# Epoch 26/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 5.9901e-04 - root_mean_squared_error: 0.0243 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0439
# Epoch 27/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 4.6618e-04 - root_mean_squared_error: 0.0215 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0480
# Epoch 28/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 4.9766e-04 - root_mean_squared_error: 0.0222 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0544
# Epoch 29/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 4.8693e-04 - root_mean_squared_error: 0.0220 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0657
# Epoch 30/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6273e-04 - root_mean_squared_error: 0.0257 - val_loss: 8.6915e-04 - val_root_mean_squared_error: 0.0295
# Epoch 31/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 3.4878e-04 - root_mean_squared_error: 0.0186 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0594
# Epoch 32/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 4.8539e-04 - root_mean_squared_error: 0.0220 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0370
# Epoch 33/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 3.6977e-04 - root_mean_squared_error: 0.0192 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0382
# Epoch 34/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 4.9614e-04 - root_mean_squared_error: 0.0223 - val_loss: 9.7462e-04 - val_root_mean_squared_error: 0.0312
# Epoch 35/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 4.0738e-04 - root_mean_squared_error: 0.0202 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0548
# Epoch 36/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 6.2011e-04 - root_mean_squared_error: 0.0249 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0402
# Epoch 37/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 4.0568e-04 - root_mean_squared_error: 0.0201 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0549
# Epoch 38/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 7.5682e-04 - root_mean_squared_error: 0.0274 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0333
# Epoch 39/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 5.3822e-04 - root_mean_squared_error: 0.0229 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0731
# Epoch 40/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - loss: 4.2696e-04 - root_mean_squared_error: 0.0206 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0482
# Epoch 41/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 6.0844e-04 - root_mean_squared_error: 0.0246 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0538
# Epoch 42/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 5.1222e-04 - root_mean_squared_error: 0.0225 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0649
# Epoch 43/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 0.0013 - root_mean_squared_error: 0.0352 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 44/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 8.0286e-04 - root_mean_squared_error: 0.0283 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0493
# Epoch 45/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 6.6891e-04 - root_mean_squared_error: 0.0258 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0341
# Epoch 46/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 0.0012 - root_mean_squared_error: 0.0344 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0781
# Epoch 47/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - root_mean_squared_error: 0.0327 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0515
# Epoch 48/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 6.3237e-04 - root_mean_squared_error: 0.0251 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0637
# Epoch 49/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 5.8888e-04 - root_mean_squared_error: 0.0242 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0499
# Epoch 50/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 0.0011 - root_mean_squared_error: 0.0324 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0422

# %%
# Make predictions
predictions_scaled = model.predict(X_test)
predictions_scaled
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# array([[0.43865064],
#        [0.42088386],
#        [0.41726163],
#        [0.4220751 ],
#        [0.4267024 ],
#        [0.40999827],
#        [0.40349436],
#        [0.39516047],
#        [0.3934284 ],
#        [0.39845747],
#        [0.38152686],
#        [0.38364002],
#        [0.37632805],
#        [0.39178795],
#        [0.3676508 ],
#        [0.36718327],
#        [0.3538078 ],
#        [0.35592377],
#        [0.34995568],
#        [0.34381208],
#        [0.36683816],
#        [0.4011674 ],
#        [0.3497285 ],
#        [0.3488195 ],
#        [0.3415181 ],
#        [0.31563413],
#        [0.32984853],
#        [0.31434527],
#        [0.30935547],
#        [0.3159599 ],
#        [0.3144485 ],
#        [0.3272269 ],
#        [0.3397593 ],
#        [0.32853812],
#        [0.3175192 ],
#        [0.3274388 ],
#        [0.3376469 ],
#        [0.32954982],
#        [0.33795443],
#        [0.33372775],
#        [0.33152032],
#        [0.34750447],
#        [0.358925  ],
#        [0.37067994],
#        [0.37819573],
#        [0.35499418],
#        [0.39762464],
#        [0.39095128],
#        [0.38280103],
#        [0.35960498],
#        [0.35348967],
#        [0.35273635],
#        [0.37436497],
#        [0.36401853],
#        [0.37691334],
#        [0.39203075],
#        [0.3752585 ],
#        [0.36130938],
#        [0.3783123 ],
#        [0.40408006],
#        [0.3704704 ],
#        [0.38422984],
#        [0.37819144],
#        [0.40515146],
#        [0.39753196],
#        [0.38358408],
#        [0.37670016],
#        [0.37405074],
#        [0.34581062],
#        [0.36298347],
#        [0.35288608],
#        [0.3550798 ],
#        [0.34348646],
#        [0.32164714],
#        [0.33574337],
#        [0.34179243],
#        [0.33417717],
#        [0.33283105],
#        [0.38724342],
#        [0.4190702 ],
#        [0.38330156],
#        [0.44149777],
#        [0.4466874 ],
#        [0.4401603 ],
#        [0.45056835],
#        [0.49213782],
#        [0.49740103],
#        [0.52097   ],
#        [0.5367955 ],
#        [0.53640056],
#        [0.506126  ],
#        [0.5212664 ],
#        [0.5196275 ],
#        [0.51586825],
#        [0.5136043 ],
#        [0.50894696],
#        [0.5247797 ],
#        [0.512376  ],
#        [0.505996  ],
#        [0.47617283],
#        [0.4742172 ],
#        [0.46603832],
#        [0.43876064],
#        [0.45722634],
#        [0.44277778],
#        [0.5040386 ],
#        [0.47228828],
#        [0.47581652],
#        [0.44814172],
#        [0.44297326],
#        [0.42762962],
#        [0.41698608],
#        [0.40533993],
#        [0.4352672 ],
#        [0.38607106],
#        [0.4010754 ],
#        [0.3904142 ],
#        [0.38347673],
#        [0.37102926],
#        [0.33536184],
#        [0.33518666],
#        [0.34148175],
#        [0.3709894 ],
#        [0.34756476],
#        [0.3404594 ],
#        [0.35154757],
#        [0.3406477 ],
#        [0.3350394 ],
#        [0.3409324 ],
#        [0.35361797],
#        [0.3404497 ],
#        [0.3344828 ],
#        [0.32170132],
#        [0.335441  ],
#        [0.34863916],
#        [0.3338057 ],
#        [0.32791618],
#        [0.31340453],
#        [0.31023332],
#        [0.30815136],
#        [0.31535727],
#        [0.3108928 ],
#        [0.29501966],
#        [0.2982014 ],
#        [0.31899607],
#        [0.37658584],
#        [0.34022677],
#        [0.34520853],
#        [0.33343428],
#        [0.3331521 ],
#        [0.3473083 ],
#        [0.3371347 ],
#        [0.3317092 ],
#        [0.33601478],
#        [0.3458403 ],
#        [0.33598736],
#        [0.3362487 ],
#        [0.32522812],
#        [0.3141014 ],
#        [0.28895363],
#        [0.3132441 ],
#        [0.2922933 ],
#        [0.29154468],
#        [0.30062428],
#        [0.29084933],
#        [0.29671067],
#        [0.29194912],
#        [0.28768116],
#        [0.284798  ],
#        [0.30637136],
#        [0.3288127 ],
#        [0.3299238 ],
#        [0.32586384],
#        [0.37317014],
#        [0.3618112 ],
#        [0.3663747 ],
#        [0.33497402],
#        [0.32263422],
#        [0.3284053 ],
#        [0.35878927],
#        [0.34587008],
#        [0.36439472],
#        [0.37053284],
#        [0.36749345],
#        [0.40212762],
#        [0.39289623],
#        [0.4250016 ],
#        [0.4324795 ],
#        [0.42086563],
#        [0.4746152 ],
#        [0.45952126],
#        [0.45401135],
#        [0.442782  ],
#        [0.4494227 ],
#        [0.50115716],
#        [0.48067102],
#        [0.5137678 ],
#        [0.4843779 ],
#        [0.47483227],
#        [0.4784594 ],
#        [0.45710048],
#        [0.4428118 ],
#        [0.44602242],
#        [0.45584324],
#        [0.45336902],
#        [0.44730407],
#        [0.4650745 ],
#        [0.44944277],
#        [0.45282912],
#        [0.48054332],
#        [0.4769409 ],
#        [0.4923917 ],
#        [0.48732895],
#        [0.5350891 ],
#        [0.5016314 ],
#        [0.4921489 ],
#        [0.49238858],
#        [0.4671917 ],
#        [0.46237287],
#        [0.46537638],
#        [0.4353717 ],
#        [0.44879588],
#        [0.45142847],
#        [0.41678116],
#        [0.43117866],
#        [0.39887258],
#        [0.4388522 ],
#        [0.41749138],
#        [0.44572264],
#        [0.42944688],
#        [0.41063407],
#        [0.40591207],
#        [0.4160345 ],
#        [0.39087185],
#        [0.3978037 ],
#        [0.40009785],
#        [0.41749468],
#        [0.3926836 ],
#        [0.38825965],
#        [0.39478594],
#        [0.3778858 ],
#        [0.3875189 ],
#        [0.35225722],
#        [0.36998427],
#        [0.36076272],
#        [0.34820285],
#        [0.35452884],
#        [0.38639572],
#        [0.36043438],
#        [0.39223754],
#        [0.3542687 ],
#        [0.36650056],
#        [0.37679094],
#        [0.41664693],
#        [0.3838885 ],
#        [0.3900666 ],
#        [0.4099474 ],
#        [0.3852407 ],
#        [0.37030736],
#        [0.37010112],
#        [0.36207753],
#        [0.36397737],
#        [0.35105467],
#        [0.33654878],
#        [0.3320531 ],
#        [0.31887758],
#        [0.32571515],
#        [0.30680773],
#        [0.2995626 ],
#        [0.31039324],
#        [0.33040354],
#        [0.32226792],
#        [0.31545994],
#        [0.3146344 ],
#        [0.31147826],
#        [0.30902952],
#        [0.29911476],
#        [0.29855236],
#        [0.3145342 ],
#        [0.31931046],
#        [0.3206203 ],
#        [0.3193497 ],
#        [0.32774252],
#        [0.30252507],
#        [0.31902313],
#        [0.3204086 ],
#        [0.35585123],
#        [0.33491313],
#        [0.3446892 ],
#        [0.33351693],
#        [0.3235959 ],
#        [0.32718718],
#        [0.316494  ],
#        [0.31922418],
#        [0.31612483],
#        [0.33568785],
#        [0.38230714],
#        [0.36743242],
#        [0.40357015],
#        [0.38455972],
#        [0.3879304 ],
#        [0.4162323 ],
#        [0.4410528 ],
#        [0.44761613],
#        [0.4739243 ],
#        [0.4466144 ],
#        [0.4531491 ],
#        [0.43306857],
#        [0.43459097],
#        [0.44418734],
#        [0.40735263],
#        [0.45330483],
#        [0.42934874],
#        [0.42300302],
#        [0.447869  ],
#        [0.4545699 ],
#        [0.45601198],
#        [0.44319028],
#        [0.47657675],
#        [0.51083785],
#        [0.49651083],
#        [0.48934937],
#        [0.47646275],
#        [0.45648217],
#        [0.45808518],
#        [0.44127715],
#        [0.44171992],
#        [0.45186797],
#        [0.4580849 ],
#        [0.46699196],
#        [0.4464873 ],
#        [0.42734605],
#        [0.41902223],
#        [0.42400876],
#        [0.4275077 ],
#        [0.4351749 ],
#        [0.42875573],
#        [0.43530753],
#        [0.4407957 ],
#        [0.41773835],
#        [0.43136802],
#        [0.40723673],
#        [0.39621136],
#        [0.3941675 ],
#        [0.3884256 ],
#        [0.38443738],
#        [0.3706833 ],
#        [0.3739843 ],
#        [0.37249997],
#        [0.3681675 ],
#        [0.35658318],
#        [0.34607115],
#        [0.4125823 ]], dtype=float32)

# %%
preds = pd.DataFrame({
    'Target': y_test,
    'Predictions': predictions_scaled.flatten()
})

preds[['Target', 'Predictions']] = target_scaler.inverse_transform(preds[['Target', 'Predictions']])
preds
# Out:
#       Target  Predictions
# 0    2053.13  2020.877811
# 1    2054.98  1983.602765
# 2    2057.84  1976.003246
# 3    2039.54  1986.101986
# 4    2022.62  1995.810190
# ..       ...          ...
# 348  1972.09  1882.092392
# 349  1960.30  1873.002757
# 350  2078.00  1848.698639
# 351  2007.69  1826.644202
# 352  2017.03  1966.185934
#
# [353 rows x 2 columns]

# %%
rmse = sqrt(mean_squared_error(preds['Target'], preds['Predictions']))
rmse
# Out:
# 85.27651685334615
