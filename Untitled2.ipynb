# %%
import pandas as pd
import numpy as np
from datetime import datetime, date, time
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./Historic Index Data.csv", index_col = 'Date') #load data making date the index
data.index = pd.to_datetime(data.index, format = '%d/%m/%Y') # convert the date to datetime type
data = data.drop("S.N.", axis = 1) # drop the S.N. column
data = data.iloc[::-1] # reverse the data to go from past to future dates

# %%
data = data[data["Turnover"] != '0'] # Remove rows where turnover == 0
data.head()
# Out:
#                 Open      High       Low     Close  Change  Per Change (%)  \
# Date
# 2016-05-29  1,522.25  1,522.25  1,522.25  1,522.25   -2.84           -0.19
# 2016-05-30  1,526.96  1,526.96  1,526.96  1,526.96    4.71            0.31
# 2016-05-31  1,532.12  1,532.12  1,532.12  1,532.12    5.16            0.34
# 2016-06-01  1,523.56  1,523.56  1,523.56  1,523.56   -8.56           -0.56
# 2016-06-02  1,518.12  1,518.12  1,518.12  1,518.12   -5.44           -0.36
#
#                     Turnover
# Date
# 2016-05-29  1,152,870,016.00
# 2016-05-30  1,148,169,984.00
# 2016-05-31  1,298,520,064.00
# 2016-06-01  1,196,009,984.00
# 2016-06-02  1,009,539,968.00

# %%
# convert to numerica value
data = data[["Open", "High", "Low", "Close", "Turnover"]]
data = data.replace({',': ''}, regex=True).astype(float)
data.head()
# Out:
#                Open     High      Low    Close      Turnover
# Date
# 2016-05-29  1522.25  1522.25  1522.25  1522.25  1.152870e+09
# 2016-05-30  1526.96  1526.96  1526.96  1526.96  1.148170e+09
# 2016-05-31  1532.12  1532.12  1532.12  1532.12  1.298520e+09
# 2016-06-01  1523.56  1523.56  1523.56  1523.56  1.196010e+09
# 2016-06-02  1518.12  1518.12  1518.12  1518.12  1.009540e+09

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1833 entries, 2016-05-29 to 2024-05-16
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Open      1833 non-null   float64
#  1   High      1833 non-null   float64
#  2   Low       1833 non-null   float64
#  3   Close     1833 non-null   float64
#  4   Turnover  1833 non-null   float64
# dtypes: float64(5)
# memory usage: 85.9 KB

# %% [markdown]
# ## Create Technical Indicators

# %%
def calculate_atr(data, window): # Average True Rate
    data['Previous Close'] = data['Close'].shift(1)
    data['TR'] = data[['High', 'Low', 'Previous Close']].apply(lambda x: max(x['High'] - x['Low'], abs(x['High'] - x['Previous Close']), abs(x['Previous Close'] - x['Low'])), axis=1)
    atr = data['TR'].rolling(window=window).mean()
    data.drop(['Previous Close', 'TR'], axis=1, inplace=True)  # Clean up intermediate columns
    return atr

# %%
# Calculate RSI
def calculate_rsi(data, window):
    delta = data['Close'].diff(1)
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

# %%
# Calculate Moving Average (MA)
def calculate_ma(data, window):
    return data['Close'].rolling(window=window).mean()

# %%
# Calculate Exponential Moving Average (EMA)
def calculate_ema(data, span):
    return data['Close'].ewm(span=span, adjust=False).mean()

# %%
# Calculate MACD
def calculate_macd(data, short_window, long_window):
    short_ema = calculate_ema(data, short_window)
    long_ema = calculate_ema(data, long_window)
    macd = long_ema - short_ema 
    return macd

# %%
# Define windows for calculations
rsi_window = 14
ma_window = 14
atr_window = 14
short_ema_window = 12
long_ema_window = 26
mfi_window = 14

# %%
# Add calculated indicators to the DataFrame
data['RSI'] = calculate_rsi(data, rsi_window)
data['MA'] = calculate_ma(data, ma_window)
data['12-day EMA'] = calculate_ema(data, short_ema_window)
data['26-day EMA'] = calculate_ema(data, long_ema_window)
data['MACD'] = calculate_macd(data, short_ema_window, long_ema_window)
data['ATR'] = calculate_atr(data,atr_window)
data.head(20)
# Out:
#                Open     High      Low    Close      Turnover        RSI  \
# Date
# 2016-05-29  1522.25  1522.25  1522.25  1522.25  1.152870e+09        NaN
# 2016-05-30  1526.96  1526.96  1526.96  1526.96  1.148170e+09        NaN
# 2016-05-31  1532.12  1532.12  1532.12  1532.12  1.298520e+09        NaN
# 2016-06-01  1523.56  1523.56  1523.56  1523.56  1.196010e+09        NaN
# 2016-06-02  1518.12  1518.12  1518.12  1518.12  1.009540e+09        NaN
# 2016-06-05  1483.14  1483.14  1483.14  1483.14  1.246660e+09        NaN
# 2016-06-06  1483.21  1516.80  1483.21  1516.80  1.078500e+09        NaN
# 2016-06-07  1516.80  1537.98  1516.80  1531.49  1.123600e+09        NaN
# 2016-06-08  1531.49  1547.65  1529.24  1546.80  1.269300e+09        NaN
# 2016-06-09  1566.70  1566.70  1566.70  1566.70  1.867000e+09        NaN
# 2016-06-12  1566.70  1602.00  1564.45  1597.96  1.919480e+09        NaN
# 2016-06-13  1597.96  1626.03  1595.86  1609.59  1.671020e+09        NaN
# 2016-06-14  1614.15  1614.15  1614.15  1614.15  1.676820e+09        NaN
# 2016-06-15  1620.47  1620.47  1620.47  1620.47  1.369690e+09  75.033133
# 2016-06-16  1632.94  1632.94  1632.94  1632.94  1.997390e+09  76.525282
# 2016-06-19  1632.94  1637.27  1617.51  1622.27  1.463940e+09  72.205396
# 2016-06-20  1632.94  1625.76  1609.38  1615.10  1.115450e+09  69.153356
# 2016-06-21  1615.22  1628.92  1615.22  1628.81  1.196110e+09  73.729540
# 2016-06-22  1628.81  1651.86  1628.84  1647.51  1.751960e+09  77.526273
# 2016-06-23  1648.17  1670.71  1648.17  1666.29  1.894710e+09  91.847553
#
#                      MA   12-day EMA   26-day EMA       MACD        ATR  Year  \
# Date
# 2016-05-29          NaN  1522.250000  1522.250000   0.000000        NaN  2016
# 2016-05-30          NaN  1522.974615  1522.598889  -0.375726        NaN  2016
# 2016-05-31          NaN  1524.381598  1523.304156  -1.077441        NaN  2016
# 2016-06-01          NaN  1524.255198  1523.323108  -0.932090        NaN  2016
# 2016-06-02          NaN  1523.311321  1522.937692  -0.373629        NaN  2016
# 2016-06-05          NaN  1517.131118  1519.989715   2.858597        NaN  2016
# 2016-06-06          NaN  1517.080177  1519.753440   2.673263        NaN  2016
# 2016-06-07          NaN  1519.297073  1520.622815   1.325742        NaN  2016
# 2016-06-08          NaN  1523.528292  1522.561866  -0.966427        NaN  2016
# 2016-06-09          NaN  1530.170093  1525.831357  -4.338737        NaN  2016
# 2016-06-12          NaN  1540.599310  1531.174219  -9.425090        NaN  2016
# 2016-06-13          NaN  1551.213262  1536.982796 -14.230466        NaN  2016
# 2016-06-14          NaN  1560.895837  1542.698885 -18.196952        NaN  2016
# 2016-06-15  1550.722143  1570.061093  1548.459708 -21.601385  16.471429  2016
# 2016-06-16  1558.628571  1579.734771  1554.717508 -25.017263  17.362143  2016
# 2016-06-19  1565.436429  1586.278652  1559.721396 -26.557256  18.437143  2016
# 2016-06-20  1571.363571  1590.712706  1563.823515 -26.889191  19.238571  2016
# 2016-06-21  1578.881429  1596.573828  1568.637329 -27.936500  19.614286  2016
# 2016-06-22  1588.123571  1604.410162  1574.479749 -29.930414  20.872143  2016
# 2016-06-23  1601.205714  1613.930137  1581.280508 -32.649629  20.030714  2016
#
#             Month
# Date
# 2016-05-29      5
# 2016-05-30      5
# 2016-05-31      5
# 2016-06-01      6
# 2016-06-02      6
# 2016-06-05      6
# 2016-06-06      6
# 2016-06-07      6
# 2016-06-08      6
# 2016-06-09      6
# 2016-06-12      6
# 2016-06-13      6
# 2016-06-14      6
# 2016-06-15      6
# 2016-06-16      6
# 2016-06-19      6
# 2016-06-20      6
# 2016-06-21      6
# 2016-06-22      6
# 2016-06-23      6

# %% [markdown]
# ## Load the MacroEconomic Data

# %%
macro_economics  = pd.read_csv("./Macro_Economic.csv", index_col = 'Date')
macro_economics.index = pd.to_datetime(macro_economics.index, format = '%Y-%m').to_period('M')
macro_economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 108 entries, 2015-07 to 2024-06
# Freq: M
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Inflation Rate(%)        106 non-null    float64
#  1   Remittance (in Billons)  94 non-null     float64
#  2   Treasury Bill            96 non-null     float64
#  3   Commercial Bank rates    96 non-null     float64
#  4   CPI                      100 non-null    float64
#  5   Exchange Rate            102 non-null    float64
# dtypes: float64(6)
# memory usage: 5.9 KB

# %%
macro_economics["Year"] = macro_economics.index.year
macro_economics["Month"] = macro_economics.index.month
macro_economics.head()
# Out:
#          Inflation Rate(%)  Remittance (in Billons)  Treasury Bill  \
# Date
# 2015-07                6.9                      NaN            NaN
# 2015-08                7.2                      NaN            NaN
# 2015-09                8.2                      NaN            NaN
# 2015-10               10.4                      NaN            NaN
# 2015-11               11.6                      NaN            NaN
#
#          Commercial Bank rates  CPI  Exchange Rate  Year  Month
# Date
# 2015-07                    NaN  NaN            NaN  2015      7
# 2015-08                    NaN  NaN            NaN  2015      8
# 2015-09                    NaN  NaN            NaN  2015      9
# 2015-10                    NaN  NaN            NaN  2015     10
# 2015-11                    NaN  NaN            NaN  2015     11

# %%
data['Year'] = data.index.year
data['Month'] = data.index.month
data.head()
# Out:
#                Open     High      Low    Close      Turnover  RSI  MA  \
# Date
# 2016-05-29  1522.25  1522.25  1522.25  1522.25  1.152870e+09  NaN NaN
# 2016-05-30  1526.96  1526.96  1526.96  1526.96  1.148170e+09  NaN NaN
# 2016-05-31  1532.12  1532.12  1532.12  1532.12  1.298520e+09  NaN NaN
# 2016-06-01  1523.56  1523.56  1523.56  1523.56  1.196010e+09  NaN NaN
# 2016-06-02  1518.12  1518.12  1518.12  1518.12  1.009540e+09  NaN NaN
#
#              12-day EMA   26-day EMA      MACD  ATR  Year  Month
# Date
# 2016-05-29  1522.250000  1522.250000  0.000000  NaN  2016      5
# 2016-05-30  1522.974615  1522.598889 -0.375726  NaN  2016      5
# 2016-05-31  1524.381598  1523.304156 -1.077441  NaN  2016      5
# 2016-06-01  1524.255198  1523.323108 -0.932090  NaN  2016      6
# 2016-06-02  1523.311321  1522.937692 -0.373629  NaN  2016      6

# %%
merged_data = pd.merge(data, macro_economics, on = ['Year', 'Month'], how = 'left')
merged_data.index = data.index

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1833 entries, 2016-05-29 to 2024-05-16
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Open                     1833 non-null   float64
#  1   High                     1833 non-null   float64
#  2   Low                      1833 non-null   float64
#  3   Close                    1833 non-null   float64
#  4   Turnover                 1833 non-null   float64
#  5   RSI                      1820 non-null   float64
#  6   MA                       1820 non-null   float64
#  7   12-day EMA               1833 non-null   float64
#  8   26-day EMA               1833 non-null   float64
#  9   MACD                     1833 non-null   float64
#  10  ATR                      1820 non-null   float64
#  11  Year                     1833 non-null   int32
#  12  Month                    1833 non-null   int32
#  13  Inflation Rate(%)        1822 non-null   float64
#  14  Remittance (in Billons)  1797 non-null   float64
#  15  Treasury Bill            1822 non-null   float64
#  16  Commercial Bank rates    1822 non-null   float64
#  17  CPI                      1822 non-null   float64
#  18  Exchange Rate            1833 non-null   float64
# dtypes: float64(17), int32(2)
# memory usage: 336.6 KB

# %% [markdown]
# ### Add temporal indicators

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(data['Close'], model='multiplicative',period = 90)
fig = plt.figure()
fig = decomposition.plot()
fig.set_size_inches(20,7)
plt.show()

# %%
merged_data['Trend'] = decomposition.trend
merged_data['Seasonality'] = decomposition.seasonal
merged_data['Residue'] = decomposition.resid

# %% [markdown]
# ## Create target variable

# %%
merged_data['Target'] = merged_data['Close'].shift(-1)
merged_data_1 = merged_data.dropna().copy()
merged_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1743 entries, 2016-08-02 to 2024-03-05
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Open                     1743 non-null   float64
#  1   High                     1743 non-null   float64
#  2   Low                      1743 non-null   float64
#  3   Close                    1743 non-null   float64
#  4   Turnover                 1743 non-null   float64
#  5   RSI                      1743 non-null   float64
#  6   MA                       1743 non-null   float64
#  7   12-day EMA               1743 non-null   float64
#  8   26-day EMA               1743 non-null   float64
#  9   MACD                     1743 non-null   float64
#  10  ATR                      1743 non-null   float64
#  11  Year                     1743 non-null   int32
#  12  Month                    1743 non-null   int32
#  13  Inflation Rate(%)        1743 non-null   float64
#  14  Remittance (in Billons)  1743 non-null   float64
#  15  Treasury Bill            1743 non-null   float64
#  16  Commercial Bank rates    1743 non-null   float64
#  17  CPI                      1743 non-null   float64
#  18  Exchange Rate            1743 non-null   float64
#  19  Trend                    1743 non-null   float64
#  20  Seasonality              1743 non-null   float64
#  21  Residue                  1743 non-null   float64
#  22  Target                   1743 non-null   float64
# dtypes: float64(21), int32(2)
# memory usage: 313.2 KB

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model1 = LinearRegression()

# %%
predictors = ['Open', 'High', 'Low', 'Turnover', 'RSI', 'MA', 
              'MACD', 'ATR', 'Inflation Rate(%)', 'Remittance (in Billons)', 'Treasury Bill',
              'Commercial Bank rates', 'CPI', 'Exchange Rate','Close', 'Trend', 'Seasonality']

# %%
from sklearn.preprocessing import MinMaxScaler

feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()
merged_data_scaled = feature_scaler.fit_transform(merged_data_1[predictors])
merged_data_scaled = pd.DataFrame(merged_data_scaled, columns = predictors, index = merged_data_1.index)
merged_data_scaled["Target"] = target_scaler.fit_transform(merged_data_1[['Target']])
merged_data_scaled.head()
# Out:
#                 Open      High       Low  Turnover       RSI        MA  \
# Date
# 2016-08-02  0.353230  0.349765  0.348961  0.062898  0.737747  0.343566
# 2016-08-03  0.344243  0.342599  0.335127  0.057387  0.710527  0.347891
# 2016-08-04  0.338194  0.334277  0.322043  0.064677  0.573082  0.349660
# 2016-08-07  0.316785  0.330371  0.317504  0.068916  0.521996  0.350326
# 2016-08-08  0.314944  0.311707  0.277434  0.039318  0.311480  0.346444
#
#                 MACD       ATR  Inflation Rate(%)  Remittance (in Billons)  \
# Date
# 2016-08-02  0.265050  0.268028           0.883281                 0.050806
# 2016-08-03  0.286391  0.276588           0.883281                 0.050806
# 2016-08-04  0.322385  0.284799           0.883281                 0.050806
# 2016-08-07  0.354210  0.294508           0.883281                 0.050806
# 2016-08-08  0.413790  0.335513           0.883281                 0.050806
#
#             Treasury Bill  Commercial Bank rates       CPI  Exchange Rate  \
# Date
# 2016-08-02        0.02881                0.09434  0.042939       0.177547
# 2016-08-03        0.02881                0.09434  0.042939       0.177547
# 2016-08-04        0.02881                0.09434  0.042939       0.177547
# 2016-08-07        0.02881                0.09434  0.042939       0.177547
# 2016-08-08        0.02881                0.09434  0.042939       0.177547
#
#                Close     Trend  Seasonality    Target
# Date
# 2016-08-02  0.345988  0.322940     0.188458  0.339911
# 2016-08-03  0.339911  0.324593     0.314560  0.318405
# 2016-08-04  0.318405  0.326221     0.150777  0.316556
# 2016-08-07  0.316556  0.327843     0.166502  0.274225
# 2016-08-08  0.274225  0.329428     0.325460  0.314506

# %% [markdown]
# ### Create function to backtest the model

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors],train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index = test.index, name = "Predictions")
    combined = pd.concat([test["Target"], preds], axis = 1)
    return combined

# %%
def backtest(data, model, predictors, start=600, step=200):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i]
        test = data.iloc[i:(i+step)]
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    
    return pd.concat(all_predictions)

# %%
preds = backtest(merged_data_scaled, model1, predictors)
preds[['Target','Predictions']] = target_scaler.inverse_transform(preds[['Target', 'Predictions']])
preds
# Out:
#              Target  Predictions
# Date
# 2019-02-25  1102.56  1111.174246
# 2019-02-26  1105.53  1101.812315
# 2019-02-27  1100.58  1104.461953
# 2019-03-03  1102.64  1101.574514
# 2019-03-05  1111.76  1105.267600
# ...             ...          ...
# 2024-02-28  1972.09  1992.217751
# 2024-02-29  1960.30  1959.717252
# 2024-03-03  2078.00  1954.001250
# 2024-03-04  2007.69  2065.230015
# 2024-03-05  2017.03  1982.950322
#
# [1143 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse = mean_squared_error(preds['Target'], preds['Predictions'])
rmse = sqrt(mse)

# %%
rmse
# Out:
# 30.080839016093247

# %%
sorted(zip(model1.coef_, predictors), reverse = True)
# Out:
# [(1.2947502904388613, 'Close'),
#  (0.14430672587111942, 'Open'),
#  (0.11133890970864134, 'Trend'),
#  (0.008601082557683343, 'Turnover'),
#  (0.005472046818703169, 'Treasury Bill'),
#  (0.0044532455502317375, 'Inflation Rate(%)'),
#  (0.0034227081796567396, 'RSI'),
#  (-0.001048338588229774, 'ATR'),
#  (-0.0015826743510100425, 'Remittance (in Billons)'),
#  (-0.0018198942248256224, 'Seasonality'),
#  (-0.0021958327181279855, 'Exchange Rate'),
#  (-0.0031542512622623462, 'Commercial Bank rates'),
#  (-0.0042590129049802855, 'CPI'),
#  (-0.016580994832319708, 'MACD'),
#  (-0.019516680963938, 'MA'),
#  (-0.1895095005966856, 'Low'),
#  (-0.359450813054941, 'High')]

# %%
preds.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Without Backtesting

# %%
X_train = merged_data_scaled[predictors][:1400]
y_train = merged_data_scaled['Target'][:1400]
X_test = merged_data_scaled[predictors][1400:]
y_test = merged_data_scaled['Target'][1400:]
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1400, 17), (343, 17), (1400,), (343,))

# %%
model1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
preds_no_back_testing = model1.predict(X_test)
y_test = y_test[y_test.isnull() == False]

# %%
mse = mean_squared_error(y_test, preds_no_back_testing)
mse
# Out:
# 0.00014869073733163074

# %%
preds_no_back_testing = pd.Series(preds_no_back_testing , index = X_test.index, name = 'Predictions')
result = pd.concat([y_test, preds_no_back_testing ], axis = 1)
result.head()
# Out:
#               Target  Predictions
# Date
# 2022-09-01  0.414696     0.415834
# 2022-09-02  0.417880     0.412804
# 2022-09-04  0.415835     0.416011
# 2022-09-05  0.405744     0.412864
# 2022-09-06  0.400044     0.403309

# %%
result.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
model_random_forest = RandomForestRegressor(n_estimators = 200, min_samples_split = 50, random_state = 47)

# %%
preds_rf = backtest( merged_data_scaled,model_random_forest, predictors)
preds_rf = preds_rf.dropna()

# %%
mse_1 = mean_squared_error(preds_rf['Target'], preds_rf['Predictions'])
mse_1
# Out:
# 0.023120623307200654

# %%
preds_rf.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ### Prepare the data for LSTM

# %%
def create_sequences(data, window_size=5):
    sequences = []
    targets = []
    for i in range(len(data) - window_size):
        sequences.append(data.iloc[i:i + window_size, :-1].values)  # Exclude last column (Target) for X
        targets.append(data.iloc[i + window_size, -1])  # Last column (Target) for y
    return np.array(sequences), np.array(targets)

# %%
window_size = 5
lstm_data_scaled = feature_scaler.fit_transform(merged_data_1[predictors])
target_scaled = target_scaler.fit_transform(merged_data_1[['Target']])
lstm_data = np.concatenate((lstm_data_scaled, target_scaled), axis=1)

# %%
X, y = create_sequences(pd.DataFrame(lstm_data, columns = predictors + ['Target']), window_size)

# %%
train_size = int(0.7 * len(X))
val_size = int(0.1 * len(X))
test_size = len(X) - train_size - val_size

X_train, X_val, X_test = X[:train_size], X[train_size:train_size + val_size], X[train_size + val_size:]
y_train, y_val, y_test = y[:train_size], y[train_size:train_size + val_size], y[train_size + val_size:]
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((1216, 5, 17), (1216,), (173, 5, 17), (173,), (349, 5, 17), (349,))

# %%
model = Sequential()
model.add(Input(shape = (window_size, X_train.shape[2])))
model.add(LSTM(30))
model.add(Dense(1, activation = "linear"))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 30)             │         5,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,791 (22.62 KB)
#  Trainable params: 5,791 (22.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer = Adam(learning_rate = 0.1), loss = MeanSquaredError(), metrics = [RootMeanSquaredError()])

# %%
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.6521 - root_mean_squared_error: 1.1392 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0442
# Epoch 2/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 0.0015 - root_mean_squared_error: 0.0391 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0391
# Epoch 3/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - loss: 7.5108e-04 - root_mean_squared_error: 0.0273 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0417
# Epoch 4/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - loss: 7.3558e-04 - root_mean_squared_error: 0.0271 - val_loss: 7.5583e-04 - val_root_mean_squared_error: 0.0275
# Epoch 5/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - loss: 7.7860e-04 - root_mean_squared_error: 0.0278 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0624
# Epoch 6/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 0.0012 - root_mean_squared_error: 0.0349 - val_loss: 7.1513e-04 - val_root_mean_squared_error: 0.0267
# Epoch 7/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - loss: 7.5168e-04 - root_mean_squared_error: 0.0273 - val_loss: 6.7866e-04 - val_root_mean_squared_error: 0.0261
# Epoch 8/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - loss: 6.2605e-04 - root_mean_squared_error: 0.0247 - val_loss: 7.5815e-04 - val_root_mean_squared_error: 0.0275
# Epoch 9/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - root_mean_squared_error: 0.0342 - val_loss: 7.7890e-04 - val_root_mean_squared_error: 0.0279
# Epoch 10/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - loss: 0.0012 - root_mean_squared_error: 0.0340 - val_loss: 7.6650e-04 - val_root_mean_squared_error: 0.0277
# Epoch 11/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 0.0012 - root_mean_squared_error: 0.0350 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0438
# Epoch 12/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 7.0938e-04 - root_mean_squared_error: 0.0265 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613
# Epoch 13/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.0018 - root_mean_squared_error: 0.0424 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0408
# Epoch 14/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 8.0022e-04 - root_mean_squared_error: 0.0282 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0445
# Epoch 15/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 8.8162e-04 - root_mean_squared_error: 0.0297 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0645
# Epoch 16/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 0.0012 - root_mean_squared_error: 0.0345 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0434
# Epoch 17/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.0012 - root_mean_squared_error: 0.0343 - val_loss: 7.7329e-04 - val_root_mean_squared_error: 0.0278
# Epoch 18/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - loss: 7.0670e-04 - root_mean_squared_error: 0.0265 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0513
# Epoch 19/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - loss: 0.0015 - root_mean_squared_error: 0.0381 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0494
# Epoch 20/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 7.3429e-04 - root_mean_squared_error: 0.0270 - val_loss: 9.4334e-04 - val_root_mean_squared_error: 0.0307
# Epoch 21/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0499
# Epoch 22/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - loss: 0.0011 - root_mean_squared_error: 0.0333 - val_loss: 7.9330e-04 - val_root_mean_squared_error: 0.0282
# Epoch 23/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.0010 - root_mean_squared_error: 0.0317 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0365
# Epoch 24/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 0.0019 - root_mean_squared_error: 0.0437 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0513
# Epoch 25/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - loss: 0.0019 - root_mean_squared_error: 0.0422 - val_loss: 8.5871e-04 - val_root_mean_squared_error: 0.0293
# Epoch 26/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.0012 - root_mean_squared_error: 0.0345 - val_loss: 8.4943e-04 - val_root_mean_squared_error: 0.0291
# Epoch 27/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - loss: 0.0014 - root_mean_squared_error: 0.0364 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0681
# Epoch 28/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - loss: 0.0021 - root_mean_squared_error: 0.0444 - val_loss: 8.7168e-04 - val_root_mean_squared_error: 0.0295
# Epoch 29/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - loss: 0.0015 - root_mean_squared_error: 0.0387 - val_loss: 8.7862e-04 - val_root_mean_squared_error: 0.0296
# Epoch 30/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 9.9581e-04 - root_mean_squared_error: 0.0314 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0374
# Epoch 31/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 0.0016 - root_mean_squared_error: 0.0401 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0407
# Epoch 32/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.0012 - root_mean_squared_error: 0.0339 - val_loss: 8.1444e-04 - val_root_mean_squared_error: 0.0285
# Epoch 33/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.0011 - root_mean_squared_error: 0.0327 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0437
# Epoch 34/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 0.0012 - root_mean_squared_error: 0.0349 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0646
# Epoch 35/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - loss: 0.0018 - root_mean_squared_error: 0.0421 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0372
# Epoch 36/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - loss: 9.7478e-04 - root_mean_squared_error: 0.0308 - val_loss: 7.5880e-04 - val_root_mean_squared_error: 0.0275
# Epoch 37/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - loss: 9.4490e-04 - root_mean_squared_error: 0.0306 - val_loss: 7.5351e-04 - val_root_mean_squared_error: 0.0275
# Epoch 38/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0435
# Epoch 39/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 9.4536e-04 - root_mean_squared_error: 0.0306 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0361
# Epoch 40/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - loss: 0.0015 - root_mean_squared_error: 0.0388 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0875
# Epoch 41/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 0.0031 - root_mean_squared_error: 0.0546 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0330
# Epoch 42/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.1181e-04 - root_mean_squared_error: 0.0296 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0685
# Epoch 43/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 0.0013 - root_mean_squared_error: 0.0357 - val_loss: 7.9377e-04 - val_root_mean_squared_error: 0.0282
# Epoch 44/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.0011 - root_mean_squared_error: 0.0330 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0393
# Epoch 45/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.0013 - root_mean_squared_error: 0.0361 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1284
# Epoch 46/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 0.0023 - root_mean_squared_error: 0.0474 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0587
# Epoch 47/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.0021 - root_mean_squared_error: 0.0441 - val_loss: 9.4244e-04 - val_root_mean_squared_error: 0.0307
# Epoch 48/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.0011 - root_mean_squared_error: 0.0327 - val_loss: 8.4211e-04 - val_root_mean_squared_error: 0.0290
# Epoch 49/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 0.0011 - root_mean_squared_error: 0.0333 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0478
# Epoch 50/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - loss: 0.0013 - root_mean_squared_error: 0.0365 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0675

# %%
# Make predictions
predictions_scaled = model.predict(X_test)
predictions_scaled
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# array([[0.40099826],
#        [0.3867136 ],
#        [0.38122782],
#        [0.37438777],
#        [0.37061068],
#        [0.3781254 ],
#        [0.35945562],
#        [0.34997943],
#        [0.360575  ],
#        [0.35460886],
#        [0.34319267],
#        [0.33839718],
#        [0.32517067],
#        [0.32633993],
#        [0.3218659 ],
#        [0.31478295],
#        [0.33010134],
#        [0.35098884],
#        [0.31762096],
#        [0.3096114 ],
#        [0.31303462],
#        [0.2777405 ],
#        [0.2901766 ],
#        [0.27296755],
#        [0.26556525],
#        [0.27541122],
#        [0.27096465],
#        [0.27986023],
#        [0.3018522 ],
#        [0.28502455],
#        [0.2765498 ],
#        [0.29216215],
#        [0.29380688],
#        [0.28224543],
#        [0.2900237 ],
#        [0.28567097],
#        [0.2815793 ],
#        [0.29649404],
#        [0.30320254],
#        [0.33195195],
#        [0.3300241 ],
#        [0.32889012],
#        [0.35792306],
#        [0.35500607],
#        [0.3460085 ],
#        [0.34008232],
#        [0.32462636],
#        [0.31842217],
#        [0.3250735 ],
#        [0.3266547 ],
#        [0.33035216],
#        [0.34505662],
#        [0.33486322],
#        [0.32522395],
#        [0.3443751 ],
#        [0.3585808 ],
#        [0.33909234],
#        [0.3466237 ],
#        [0.35049108],
#        [0.3564324 ],
#        [0.36143652],
#        [0.34508857],
#        [0.33764634],
#        [0.33675918],
#        [0.31368747],
#        [0.3230103 ],
#        [0.31816253],
#        [0.31629154],
#        [0.30918214],
#        [0.29240242],
#        [0.3009431 ],
#        [0.30610213],
#        [0.29797623],
#        [0.294719  ],
#        [0.34112713],
#        [0.35572538],
#        [0.3432218 ],
#        [0.3830146 ],
#        [0.39084575],
#        [0.38096765],
#        [0.3989332 ],
#        [0.41480765],
#        [0.4362758 ],
#        [0.4431555 ],
#        [0.4610189 ],
#        [0.4710422 ],
#        [0.43762067],
#        [0.44399908],
#        [0.4628953 ],
#        [0.44054958],
#        [0.45955536],
#        [0.44014534],
#        [0.4671472 ],
#        [0.45626864],
#        [0.45940718],
#        [0.4371765 ],
#        [0.43424204],
#        [0.4198924 ],
#        [0.41348627],
#        [0.4139922 ],
#        [0.41043493],
#        [0.44483063],
#        [0.43632302],
#        [0.42813882],
#        [0.42527506],
#        [0.40359995],
#        [0.40230778],
#        [0.3881683 ],
#        [0.37850115],
#        [0.3953028 ],
#        [0.37165812],
#        [0.3615723 ],
#        [0.36750886],
#        [0.35858563],
#        [0.3484827 ],
#        [0.33076784],
#        [0.32338962],
#        [0.326295  ],
#        [0.3458434 ],
#        [0.333387  ],
#        [0.32042804],
#        [0.33078745],
#        [0.32334968],
#        [0.31596854],
#        [0.31914672],
#        [0.32751885],
#        [0.32179514],
#        [0.3099663 ],
#        [0.30351958],
#        [0.3064082 ],
#        [0.32134995],
#        [0.30727664],
#        [0.31007478],
#        [0.30286333],
#        [0.28786585],
#        [0.2930263 ],
#        [0.2937546 ],
#        [0.28935507],
#        [0.2724752 ],
#        [0.2760189 ],
#        [0.29443815],
#        [0.32920375],
#        [0.31466147],
#        [0.31080088],
#        [0.31314883],
#        [0.30538294],
#        [0.3158438 ],
#        [0.30882058],
#        [0.30233178],
#        [0.30597356],
#        [0.31339678],
#        [0.30645677],
#        [0.30259797],
#        [0.2974064 ],
#        [0.29253104],
#        [0.27556   ],
#        [0.29265925],
#        [0.27662686],
#        [0.27088913],
#        [0.2796695 ],
#        [0.27170625],
#        [0.2735224 ],
#        [0.2707971 ],
#        [0.2629306 ],
#        [0.26599273],
#        [0.2788746 ],
#        [0.29296055],
#        [0.29850045],
#        [0.29594442],
#        [0.3263279 ],
#        [0.32528457],
#        [0.32846925],
#        [0.3059601 ],
#        [0.2933872 ],
#        [0.3013725 ],
#        [0.31433162],
#        [0.31489763],
#        [0.319115  ],
#        [0.3319076 ],
#        [0.3265904 ],
#        [0.34740725],
#        [0.34816095],
#        [0.36282167],
#        [0.37554207],
#        [0.3694907 ],
#        [0.39989647],
#        [0.40326127],
#        [0.39640215],
#        [0.38929984],
#        [0.39132717],
#        [0.41946015],
#        [0.41636565],
#        [0.428268  ],
#        [0.4260197 ],
#        [0.44226584],
#        [0.41112807],
#        [0.4161847 ],
#        [0.39250317],
#        [0.38697723],
#        [0.40091965],
#        [0.40375403],
#        [0.39542422],
#        [0.40537974],
#        [0.40123567],
#        [0.39698723],
#        [0.41530582],
#        [0.42240122],
#        [0.42781195],
#        [0.43001887],
#        [0.4588075 ],
#        [0.44868335],
#        [0.43642154],
#        [0.43585965],
#        [0.41953084],
#        [0.41329047],
#        [0.41470286],
#        [0.394191  ],
#        [0.40389195],
#        [0.40471837],
#        [0.38869694],
#        [0.38849   ],
#        [0.37887117],
#        [0.3900096 ],
#        [0.39096424],
#        [0.40236863],
#        [0.40042266],
#        [0.38661048],
#        [0.3727071 ],
#        [0.379177  ],
#        [0.3672618 ],
#        [0.3647327 ],
#        [0.36537436],
#        [0.376478  ],
#        [0.36364207],
#        [0.35635826],
#        [0.36213765],
#        [0.35089073],
#        [0.35552666],
#        [0.33621594],
#        [0.34025744],
#        [0.33890143],
#        [0.3250899 ],
#        [0.32668194],
#        [0.34757945],
#        [0.33601037],
#        [0.3512027 ],
#        [0.33557013],
#        [0.33156916],
#        [0.34583023],
#        [0.36779633],
#        [0.3525301 ],
#        [0.35408947],
#        [0.36827984],
#        [0.3545724 ],
#        [0.342509  ],
#        [0.33759752],
#        [0.33608887],
#        [0.33406356],
#        [0.32917365],
#        [0.31600472],
#        [0.30968603],
#        [0.30279705],
#        [0.30222866],
#        [0.2917076 ],
#        [0.28334352],
#        [0.2899529 ],
#        [0.3020788 ],
#        [0.302205  ],
#        [0.29109976],
#        [0.29273137],
#        [0.28924266],
#        [0.281962  ],
#        [0.27969286],
#        [0.271511  ],
#        [0.28558525],
#        [0.28916046],
#        [0.28809854],
#        [0.28897527],
#        [0.2928212 ],
#        [0.27499166],
#        [0.28331676],
#        [0.288047  ],
#        [0.3095459 ],
#        [0.30460325],
#        [0.30541584],
#        [0.30493662],
#        [0.2924026 ],
#        [0.29298207],
#        [0.28667352],
#        [0.2868385 ],
#        [0.28448883],
#        [0.2972819 ],
#        [0.32742366],
#        [0.33623347],
#        [0.33852634],
#        [0.3485951 ],
#        [0.34068295],
#        [0.35869792],
#        [0.37797388],
#        [0.38396922],
#        [0.4098377 ],
#        [0.39887723],
#        [0.39681706],
#        [0.38345966],
#        [0.3861234 ],
#        [0.3844736 ],
#        [0.36889848],
#        [0.38416657],
#        [0.38550267],
#        [0.37173793],
#        [0.38405082],
#        [0.4027606 ],
#        [0.39598474],
#        [0.39275953],
#        [0.4100577 ],
#        [0.44119707],
#        [0.44063511],
#        [0.41915432],
#        [0.41617164],
#        [0.4010379 ],
#        [0.3984762 ],
#        [0.39259276],
#        [0.38674077],
#        [0.39488867],
#        [0.40252933],
#        [0.40599558],
#        [0.39647982],
#        [0.38004878],
#        [0.37628207],
#        [0.37987718],
#        [0.3857529 ],
#        [0.39014295],
#        [0.38487515],
#        [0.39136705],
#        [0.38983908],
#        [0.38362905],
#        [0.38069317],
#        [0.37422898],
#        [0.3638235 ],
#        [0.36093274],
#        [0.3605081 ],
#        [0.35671547],
#        [0.34595773],
#        [0.34593067],
#        [0.34846446],
#        [0.34495386],
#        [0.33750394],
#        [0.32622042],
#        [0.35963556]], dtype=float32)

# %%
preds = pd.DataFrame({
    'Target': y_test,
    'Predictions': predictions_scaled.flatten()
})

preds[['Target', 'Predictions']] = target_scaler.inverse_transform(preds[['Target', 'Predictions']])
preds
# Out:
#       Target  Predictions
# 0    2022.62  1941.882379
# 1    1989.26  1911.912855
# 2    1993.02  1900.403593
# 3    1995.34  1886.053031
# 4    1973.38  1878.128628
# ..       ...          ...
# 344  1972.09  1831.665405
# 345  1960.30  1824.300107
# 346  2078.00  1808.670016
# 347  2007.69  1784.996972
# 348  2017.03  1855.102601
#
# [349 rows x 2 columns]

# %%
rmse = sqrt(mean_squared_error(preds['Target'], preds['Predictions']))
rmse
# Out:
# 154.74525268415172

# %%
preds.plot()
# Out:
# <Axes: >
