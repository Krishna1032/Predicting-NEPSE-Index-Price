# %%
import pandas as pd
import numpy as np
from datetime import datetime, date, time
import matplotlib.pyplot as plt

# %%
plt.rc('font', size = 10)
plt.rc('axes', labelsize = 10, titlesize = 12)
plt.rc('xtick', labelsize = 10)
plt.rc('ytick', labelsize = 10)
plt.rc('legend', fontsize = 10)

# %% [markdown]
# ## Load the Data

# %%
data = pd.read_csv('./Historic Index Data.csv', index_col = "Date")
data = data.iloc[::-1]

# %%
data = data.drop('S.N.', axis = 1)
data.head()
# Out:
#                 Open      High       Low     Close  Change  Per Change (%)  \
# Date
# 04/01/2016  1,154.62  1,154.62  1,154.62  1,154.62   -6.22           -0.54
# 05/01/2016  1,146.11  1,146.11  1,146.11  1,146.11   -7.85           -0.68
# 06/01/2016  1,149.89  1,149.89  1,149.89  1,149.89    3.12            0.27
# 07/01/2016  1,164.14  1,164.14  1,164.14  1,164.14   14.25            1.24
# 10/01/2016  1,167.18  1,167.18  1,167.18  1,167.18    3.04            0.26
#
#            Turnover
# Date
# 04/01/2016        0
# 05/01/2016        0
# 06/01/2016        0
# 07/01/2016        0
# 10/01/2016        0

# %% [markdown]
# ## Data analysis and Visualization

# %%
data.index = pd.to_datetime(data.index, dayfirst = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1928 entries, 2016-01-04 to 2024-05-16
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Open            1928 non-null   object
#  1   High            1928 non-null   object
#  2   Low             1928 non-null   object
#  3   Close           1928 non-null   object
#  4   Change          1928 non-null   float64
#  5   Per Change (%)  1928 non-null   float64
#  6   Turnover        1928 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 120.5+ KB

# %%
data["Turnover"].value_counts()
# Out:
# Turnover
# 0                   95
# 377,179,008.00       2
# 591,177,984.00       2
# 365,169,984.00       2
# 4,498,043,581.00     1
#                     ..
# 322,203,008.00       1
# 298,870,016.00       1
# 262,468,000.00       1
# 246,231,008.00       1
# 4,233,816,403.70     1
# Name: count, Length: 1831, dtype: int64

# %% [markdown]
# Removing the zero values in the Turnover column. They are old data.

# %%
data = data[data["Turnover"] != '0'] # remove the rows with Turnover value == 0

# %%
columns_to_convert = ['Open', 'High', 'Low', 'Close','Turnover']
data[columns_to_convert] = data[columns_to_convert].replace({',': ''}, regex=True).astype(float) # remove the unnecessary  comma ','

# %%
data.plot.line(y='Close', use_index = True, figsize = (10, 6))
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1833 entries, 2016-05-29 to 2024-05-16
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Open            1833 non-null   float64
#  1   High            1833 non-null   float64
#  2   Low             1833 non-null   float64
#  3   Close           1833 non-null   float64
#  4   Change          1833 non-null   float64
#  5   Per Change (%)  1833 non-null   float64
#  6   Turnover        1833 non-null   float64
# dtypes: float64(7)
# memory usage: 114.6 KB

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(data['Close'], model='multiplicative',period = 90)
fig = plt.figure()
fig = decomposition.plot()
fig.set_size_inches(20,7)
plt.show()

# %%
data['Seasonality'] = decomposition.seasonal
data['Trend'] = decomposition.trend

# %% [markdown]
# ### Testing for stationarity using ADF and KPSS Tests.

# %%
from statsmodels.tsa.stattools import adfuller, kpss

def stationarity_test(stock_close_price):
    # Calculating rolling mean and rolling standard deviation:
    rolling_mean = stock_close_price.rolling(30).mean()
    rolling_std_dev = stock_close_price.rolling(30).std()
  
    # Plotting the statistics:
    plt.figure(figsize=(20,7))
    plt.plot(stock_close_price, color='red', label='Original Time Series')
    plt.plot(rolling_mean, color='blue', label='Rolling Mean')
    plt.plot(rolling_std_dev, color='green', label='Rolling Std Dev')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show()
    
    # ADF Test
    print("ADF Test:")
    adf_test = adfuller(stock_close_price, autolag='AIC')
    print('Null Hypothesis: Not Stationary')
    print('ADF Statistic: %f' % adf_test[0])
    print('p-value: %f' % adf_test[1])
    print('Critical Values:')
    for key, value in adf_test[4].items():
        print('\t%s: %.3f' % (key, value))

    # KPSS Test
    print("KPSS Test:")
    kpss_test = kpss(stock_close_price, regression='c', nlags='auto')
    print('Null Hypothesis: Stationary')
    print('KPSS Statistic: %f' % kpss_test[0])
    print('p-value: %f' % kpss_test[1])
    print('Critical Values:')
    for key, value in kpss_test[3].items():
        print('\t%s: %.3f' % (key, value))

# Example usage:
stationarity_test(data['Close'])
# Out:
# ADF Test:
# Null Hypothesis: Not Stationary
# ADF Statistic: -1.385688
# p-value: 0.589118
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
# KPSS Test:
# Null Hypothesis: Stationary
# KPSS Statistic: 2.921979
# p-value: 0.010000
# Critical Values:
# 	10%: 0.347
# 	5%: 0.463
# 	2.5%: 0.574
# 	1%: 0.739
# /var/folders/rz/l9b2tkxn657c_n46x48rlqcw0000gn/T/ipykernel_52981/1272691265.py:29: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpss_test = kpss(stock_close_price, regression='c', nlags='auto')

# %% [markdown]
# Conclusion: This shows that the data that we have is highly non_stationary series data. The decomposition resudial component might be stationary.

# %%
residual = decomposition.resid.dropna()
stationarity_test(residual)
# Out:
# ADF Test:
# Null Hypothesis: Not Stationary
# ADF Statistic: -8.994979
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
# KPSS Test:
# Null Hypothesis: Stationary
# KPSS Statistic: 0.015090
# p-value: 0.100000
# Critical Values:
# 	10%: 0.347
# 	5%: 0.463
# 	2.5%: 0.574
# 	1%: 0.739
# /var/folders/rz/l9b2tkxn657c_n46x48rlqcw0000gn/T/ipykernel_52981/1272691265.py:29: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_test = kpss(stock_close_price, regression='c', nlags='auto')

# %%
residual
# Out:
# Date
# 2016-08-02    1.067498
# 2016-08-03    1.054020
# 2016-08-04    1.031415
# 2016-08-07    1.026924
# 2016-08-08    0.968767
#                 ...
# 2024-02-28    0.974484
# 2024-02-29    0.963052
# 2024-03-03    0.955349
# 2024-03-04    1.004982
# 2024-03-05    0.972863
# Name: resid, Length: 1743, dtype: float64

# %% [markdown]
# ## Building a model

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Creating a target value

# %%
data['Tomorrow'] = data["Close"].shift(-1) 
data["Target"] = (data["Tomorrow"] > data["Close"]).astype(int)

# %%
data.head()
# Out:
#                Open     High      Low    Close  Change  Per Change (%)  \
# Date
# 2016-05-29  1522.25  1522.25  1522.25  1522.25   -2.84           -0.19
# 2016-05-30  1526.96  1526.96  1526.96  1526.96    4.71            0.31
# 2016-05-31  1532.12  1532.12  1532.12  1532.12    5.16            0.34
# 2016-06-01  1523.56  1523.56  1523.56  1523.56   -8.56           -0.56
# 2016-06-02  1518.12  1518.12  1518.12  1518.12   -5.44           -0.36
#
#                 Turnover  Seasonality  Trend  Tomorrow  Target
# Date
# 2016-05-29  1.152870e+09     1.001786    NaN   1526.96       1
# 2016-05-30  1.148170e+09     0.998155    NaN   1532.12       1
# 2016-05-31  1.298520e+09     0.994329    NaN   1523.56       0
# 2016-06-01  1.196010e+09     0.993681    NaN   1518.12       0
# 2016-06-02  1.009540e+09     0.990311    NaN   1483.14       0

# %%
model = RandomForestClassifier(n_estimators = 100, min_samples_split = 100, random_state = 47)

# %% [markdown]
# ### train test split

# %%
train = data.iloc[:-100]
test = data.iloc[-100:]

# %%
predictors = ['Open', 'High', 'Low', 'Close', 'Turnover','Seasonality']

# %%
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=47)

# %% [markdown]
# ### Performance Measure

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score, roc_auc_score

# %%
preds = model.predict(test[predictors])

# %%
preds= pd.Series(preds, index = test.index)
preds
# Out:
# Date
# 2023-12-13    1
# 2023-12-14    0
# 2023-12-17    1
# 2023-12-18    0
# 2023-12-19    0
#              ..
# 2024-05-12    1
# 2024-05-13    1
# 2024-05-14    1
# 2024-05-15    1
# 2024-05-16    1
# Length: 100, dtype: int64

# %%
accuracy_score(test["Target"], preds)
# Out:
# 0.52

# %%
precision_score(test["Target"], preds)
# Out:
# 0.4444444444444444

# %%
recall_score(test["Target"], preds)
# Out:
# 0.46511627906976744

# %%
roc_auc_score(test["Target"], preds)
# Out:
# 0.5132598939208486

# %%
combined = pd.concat([test["Target"], preds], axis = 1)
combined
# Out:
#             Target  0
# Date
# 2023-12-13       1  1
# 2023-12-14       1  0
# 2023-12-17       1  1
# 2023-12-18       1  0
# 2023-12-19       1  0
# ...            ... ..
# 2024-05-12       1  1
# 2024-05-13       1  1
# 2024-05-14       0  1
# 2024-05-15       1  1
# 2024-05-16       0  1
#
# [100 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(test["Target"], preds)
matrix
# Out:
# array([[32, 25],
#        [23, 20]])

# %%
data["Target"].value_counts() / data.shape[0] # this is the natural percentage of 0's and 1's in the dataset
# Out:
# Target
# 0    0.534097
# 1    0.465903
# Name: count, dtype: float64

# %%
data_yearly = data.index.year # find how many data in average are there in each year
(data_yearly.value_counts()).mean()
# Out:
# 203.66666666666666

# %% [markdown]
# ### create a function to backtest the model

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors],train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds>=.54] = 1
    preds[preds <.54] = 0
    preds = pd.Series(preds, index = test.index, name = "Predictions")
    combined = pd.concat([test["Target"], preds], axis = 1)
    return combined

# %%
def backtest(data, model, predictors, start=600, step=200):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i]
        test = data.iloc[i:(i+step)]
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    
    return pd.concat(all_predictions)

# %%
predictions = backtest(data, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    933
# 1.0    300
# Name: count, dtype: int64

# %%
accuracy_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.505271695052717

# %%
roc_auc_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.49422727152911405

# %%
horizons = [2,5,60,200]
new_predictors = []

for horizon in horizons:
    rolling_averages = data.rolling(horizon).mean()
    
    ratio_column = f"Close_Ratio_{horizon}"
    data[ratio_column] = data["Close"] / rolling_averages["Close"]
    
    trend_column = f"Trend_{horizon}"
    data[trend_column] = data.shift(1).rolling(horizon).sum()["Target"]
    
    new_predictors+= [ratio_column, trend_column]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1833 entries, 2016-05-29 to 2024-05-16
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Open             1833 non-null   float64
#  1   High             1833 non-null   float64
#  2   Low              1833 non-null   float64
#  3   Close            1833 non-null   float64
#  4   Change           1833 non-null   float64
#  5   Per Change (%)   1833 non-null   float64
#  6   Turnover         1833 non-null   float64
#  7   Seasonality      1833 non-null   float64
#  8   Trend            1743 non-null   float64
#  9   Tomorrow         1832 non-null   float64
#  10  Target           1833 non-null   int64
#  11  Close_Ratio_2    1832 non-null   float64
#  12  Trend_2          1831 non-null   float64
#  13  Close_Ratio_5    1829 non-null   float64
#  14  Trend_5          1828 non-null   float64
#  15  Close_Ratio_60   1774 non-null   float64
#  16  Trend_60         1773 non-null   float64
#  17  Close_Ratio_200  1634 non-null   float64
#  18  Trend_200        1633 non-null   float64
# dtypes: float64(18), int64(1)
# memory usage: 286.4 KB

# %%
new_data = data.dropna(subset = data.columns[data.columns != "Tomorrow"])
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1588 entries, 2017-04-09 to 2024-03-05
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Open             1588 non-null   float64
#  1   High             1588 non-null   float64
#  2   Low              1588 non-null   float64
#  3   Close            1588 non-null   float64
#  4   Change           1588 non-null   float64
#  5   Per Change (%)   1588 non-null   float64
#  6   Turnover         1588 non-null   float64
#  7   Seasonality      1588 non-null   float64
#  8   Trend            1588 non-null   float64
#  9   Tomorrow         1588 non-null   float64
#  10  Target           1588 non-null   int64
#  11  Close_Ratio_2    1588 non-null   float64
#  12  Trend_2          1588 non-null   float64
#  13  Close_Ratio_5    1588 non-null   float64
#  14  Trend_5          1588 non-null   float64
#  15  Close_Ratio_60   1588 non-null   float64
#  16  Trend_60         1588 non-null   float64
#  17  Close_Ratio_200  1588 non-null   float64
#  18  Trend_200        1588 non-null   float64
# dtypes: float64(18), int64(1)
# memory usage: 248.1 KB

# %%
new_data.head()
# Out:
#                Open     High      Low    Close  Change  Per Change (%)  \
# Date
# 2017-04-09  1651.04  1665.55  1644.31  1651.60    0.56            0.03
# 2017-04-10  1651.60  1677.18  1651.28  1676.22   24.62            1.49
# 2017-04-11  1676.22  1710.74  1676.25  1709.82   33.60            2.00
# 2017-04-12  1709.82  1737.91  1702.70  1703.07   -6.75           -0.40
# 2017-04-13  1703.07  1709.08  1679.68  1697.13   -5.94           -0.35
#
#                 Turnover  Seasonality        Trend  Tomorrow  Target  \
# Date
# 2017-04-09  1.194230e+09     1.007994  1519.575889   1676.22       1
# 2017-04-10  1.542030e+09     1.009115  1521.916944   1709.82       1
# 2017-04-11  1.860470e+09     1.008422  1524.525056   1703.07       0
# 2017-04-12  1.986260e+09     1.012392  1526.734778   1697.13       0
# 2017-04-13  1.391820e+09     1.013395  1528.706611   1651.61       0
#
#             Close_Ratio_2  Trend_2  Close_Ratio_5  Trend_5  Close_Ratio_60  \
# Date
# 2017-04-09       1.000170      1.0       0.996466      2.0        1.165205
# 2017-04-10       1.007398      2.0       1.010209      2.0        1.179402
# 2017-04-11       1.009923      2.0       1.024372      3.0        1.199515
# 2017-04-12       0.998022      1.0       1.014729      3.0        1.191628
# 2017-04-13       0.998253      0.0       1.005666      3.0        1.184425
#
#             Trend_60  Close_Ratio_200  Trend_200
# Date
# 2017-04-09      28.0         1.031748       97.0
# 2017-04-10      29.0         1.046640       97.0
# 2017-04-11      29.0         1.067028       97.0
# 2017-04-12      28.0         1.062221       97.0
# 2017-04-13      28.0         1.057926       97.0

# %%
new_predictors += ["Seasonality", "Trend"]
new_predictors
# Out:
# ['Close_Ratio_2',
#  'Trend_2',
#  'Close_Ratio_5',
#  'Trend_5',
#  'Close_Ratio_60',
#  'Trend_60',
#  'Close_Ratio_200',
#  'Trend_200',
#  'Seasonality',
#  'Trend']

# %%
predictions = backtest(new_data, model, new_predictors)

# %%
confusion_matrix(predictions["Target"], predictions["Predictions"])
# Out:
# array([[437,  67],
#        [379, 105]])

# %%
accuracy_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.548582995951417

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.6104651162790697

# %%
recall_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.21694214876033058

# %%
predictions["Target"].value_counts()
# Out:
# Target
# 0    504
# 1    484
# Name: count, dtype: int64

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    816
# 1.0    172
# Name: count, dtype: int64

# %%
train = new_data.iloc[:-200]
test = new_data.iloc[-200:]

# %%
model.fit(train[new_predictors],train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=47)

# %%
preds = model.predict(test[new_predictors])

# %%
accuracy_score(test["Target"], preds)
# Out:
# 0.575

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.6104651162790697

# %%
recall_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.21694214876033058

# %%
test["Target"].value_counts()
# Out:
# Target
# 0    108
# 1     92
# Name: count, dtype: int64

# %%
(preds == 1).sum()
# Out:
# 55

# %%
model.feature_importances_
# Out:
# array([0.24432598, 0.01827051, 0.18216452, 0.03767119, 0.08962606,
#        0.05444375, 0.11011564, 0.07591435, 0.08092212, 0.10654589])

# %%
sorted(zip(model.feature_importances_,new_predictors), reverse = True)
# Out:
# [(0.24432597789559626, 'Close_Ratio_2'),
#  (0.18216452248868512, 'Close_Ratio_5'),
#  (0.11011564011883383, 'Close_Ratio_200'),
#  (0.10654588659565042, 'Trend'),
#  (0.08962605569919416, 'Close_Ratio_60'),
#  (0.08092211656568073, 'Seasonality'),
#  (0.07591435370085024, 'Trend_200'),
#  (0.05444374802618295, 'Trend_60'),
#  (0.03767119071176869, 'Trend_5'),
#  (0.01827050819755736, 'Trend_2')]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
