# %%
import pandas as pd
import numpy as np
from datetime import datetime, date, time
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Historic Index Data.csv")

# %%
# Convert relevant columns to numeric types
numeric_columns = ['Open', 'High', 'Low', 'Close', 'Turnover']
for column in numeric_columns:
    data[column] = pd.to_numeric(data[column].str.replace(',', ''), errors='coerce')

# %%
# Convert the 'Date' column to datetime type
data['Date'] = pd.to_datetime(data['Date'], format='%d/%m/%Y')

# %%
# Drop the 'S.N.' column if it exists
if 'S.N.' in data.columns:
    data = data.drop('S.N.', axis=1)

# %%
# Reverse the data to go from past to future dates
data = data.iloc[::-1]

# %%
# Set the 'Date' column as the index
data.set_index('Date', inplace=True)

# %%
def calculate_atr(data, window):
    data['Previous Close'] = data['Close'].shift(1)
    data['TR'] = data[['High', 'Low', 'Previous Close']].apply(lambda x: max(x['High'] - x['Low'], abs(x['High'] - x['Previous Close']), abs(x['Previous Close'] - x['Low'])), axis=1)
    atr = data['TR'].rolling(window=window).mean()
    data.drop(['Previous Close', 'TR'], axis=1, inplace=True)  # Clean up intermediate columns
    return atr

# %%
# Calculate RSI
def calculate_rsi(data, window):
    delta = data['Close'].diff(1)
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

# %%
# Calculate Moving Average (MA)
def calculate_ma(data, window):
    return data['Close'].rolling(window=window).mean()

# %%
# Calculate Exponential Moving Average (EMA)
def calculate_ema(data, span):
    return data['Close'].ewm(span=span, adjust=False).mean()

# %%
# Calculate MACD
def calculate_macd(data, short_window, long_window):
    short_ema = calculate_ema(data, short_window)
    long_ema = calculate_ema(data, long_window)
    macd = long_ema - short_ema 
    return macd

# %%
# Define windows for calculations
rsi_window = 14
ma_window = 14
atr_window = 14
short_ema_window = 12
long_ema_window = 26
mfi_window = 14

# %%
# Add calculated indicators to the DataFrame
data['RSI'] = calculate_rsi(data, rsi_window)
data['MA'] = calculate_ma(data, ma_window)
data['12-day EMA'] = calculate_ema(data, short_ema_window)
data['26-day EMA'] = calculate_ema(data, long_ema_window)
data['MACD'] = calculate_macd(data, short_ema_window, long_ema_window)
data['ATR'] = calculate_atr(data,atr_window)

# %%
data.loc['2016-07-21']
# Out:
# Open              1.786840e+03
# High              1.804750e+03
# Low               1.779710e+03
# Close             1.798830e+03
# Change            1.199000e+01
# Per Change (%)    6.700000e-01
# Turnover          1.429860e+09
# RSI               7.016430e+01
# MA                1.736406e+03
# 12-day EMA        1.749282e+03
# 26-day EMA        1.702396e+03
# MACD             -4.688594e+01
# ATR               2.619857e+01
# Name: 2016-07-21 00:00:00, dtype: float64

# %%
macro_economics  = pd.read_csv("./Macro_Economic.csv", index_col = 'Date')
macro_economics.index = pd.to_datetime(macro_economics.index, format = '%Y-%m').to_period('M')
macro_economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 108 entries, 2015-07 to 2024-06
# Freq: M
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Inflation Rate(%)        106 non-null    float64
#  1   Remittance (in Billons)  94 non-null     float64
#  2   Treasury Bill            96 non-null     float64
#  3   Commercial Bank rates    96 non-null     float64
#  4   CPI                      100 non-null    float64
#  5   Exchange Rate            102 non-null    float64
# dtypes: float64(6)
# memory usage: 5.9 KB

# %%
macro_economics["Year"] = macro_economics.index.year
macro_economics["Month"] = macro_economics.index.month
macro_economics.head()
# Out:
#          Inflation Rate(%)  Remittance (in Billons)  Treasury Bill  \
# Date
# 2015-07                6.9                      NaN            NaN
# 2015-08                7.2                      NaN            NaN
# 2015-09                8.2                      NaN            NaN
# 2015-10               10.4                      NaN            NaN
# 2015-11               11.6                      NaN            NaN
#
#          Commercial Bank rates  CPI  Exchange Rate  Year  Month
# Date
# 2015-07                    NaN  NaN            NaN  2015      7
# 2015-08                    NaN  NaN            NaN  2015      8
# 2015-09                    NaN  NaN            NaN  2015      9
# 2015-10                    NaN  NaN            NaN  2015     10
# 2015-11                    NaN  NaN            NaN  2015     11

# %%
data['Year'] = data.index.year
data['Month'] = data.index.month
data.head()
# Out:
#                Open     High      Low    Close  Change  Per Change (%)  \
# Date
# 2016-01-04  1154.62  1154.62  1154.62  1154.62   -6.22           -0.54
# 2016-01-05  1146.11  1146.11  1146.11  1146.11   -7.85           -0.68
# 2016-01-06  1149.89  1149.89  1149.89  1149.89    3.12            0.27
# 2016-01-07  1164.14  1164.14  1164.14  1164.14   14.25            1.24
# 2016-01-10  1167.18  1167.18  1167.18  1167.18    3.04            0.26
#
#             Turnover  RSI  MA   12-day EMA   26-day EMA      MACD  ATR  Year  \
# Date
# 2016-01-04       0.0  NaN NaN  1154.620000  1154.620000  0.000000  NaN  2016
# 2016-01-05       0.0  NaN NaN  1153.310769  1153.989630  0.678860  NaN  2016
# 2016-01-06       0.0  NaN NaN  1152.784497  1153.685953  0.901456  NaN  2016
# 2016-01-07       0.0  NaN NaN  1154.531497  1154.460327 -0.071170  NaN  2016
# 2016-01-10       0.0  NaN NaN  1156.477421  1155.402525 -1.074896  NaN  2016
#
#             Month
# Date
# 2016-01-04      1
# 2016-01-05      1
# 2016-01-06      1
# 2016-01-07      1
# 2016-01-10      1

# %%
merged_data = pd.merge(data, macro_economics, on = ['Year', 'Month'], how = 'left')
merged_data.index = data.index

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1928 entries, 2016-01-04 to 2024-05-16
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Open                     1928 non-null   float64
#  1   High                     1928 non-null   float64
#  2   Low                      1928 non-null   float64
#  3   Close                    1928 non-null   float64
#  4   Change                   1928 non-null   float64
#  5   Per Change (%)           1928 non-null   float64
#  6   Turnover                 1928 non-null   float64
#  7   RSI                      1915 non-null   float64
#  8   MA                       1915 non-null   float64
#  9   12-day EMA               1928 non-null   float64
#  10  26-day EMA               1928 non-null   float64
#  11  MACD                     1928 non-null   float64
#  12  ATR                      1915 non-null   float64
#  13  Year                     1928 non-null   int32
#  14  Month                    1928 non-null   int32
#  15  Inflation Rate(%)        1917 non-null   float64
#  16  Remittance (in Billons)  1797 non-null   float64
#  17  Treasury Bill            1841 non-null   float64
#  18  Commercial Bank rates    1841 non-null   float64
#  19  CPI                      1917 non-null   float64
#  20  Exchange Rate            1928 non-null   float64
# dtypes: float64(19), int32(2)
# memory usage: 380.9 KB

# %%
merged_data[merged_data['CPI'].isnull()]
# Out:
#                Open     High      Low    Close  Change  Per Change (%)  \
# Date
# 2024-05-02  2025.78  2025.78  1995.84  1998.96   -7.31           -0.36
# 2024-05-05  1998.44  1998.52  1970.23  1974.37  -24.58           -1.23
# 2024-05-06  1980.22  1980.22  1952.96  1958.75  -15.62           -0.79
# 2024-05-07  1959.91  1970.44  1955.22  1960.81    2.06            0.10
# 2024-05-08  1961.27  1967.92  1954.39  1960.60   -0.21           -0.01
# 2024-05-09  1963.45  1970.35  1955.27  1966.23    5.63            0.28
# 2024-05-12  1973.78  1981.57  1962.21  1974.50    8.26            0.42
# 2024-05-13  1979.68  2000.14  1970.64  1998.89   24.39            1.23
# 2024-05-14  2000.66  2027.51  1999.56  2027.51   28.62            1.43
# 2024-05-15  2030.87  2048.23  2013.53  2017.97   -9.54           -0.47
# 2024-05-16  2029.10  2029.10  2009.56  2018.76    0.79            0.03
#
#                 Turnover        RSI           MA   12-day EMA  ...  \
# Date                                                           ...
# 2024-05-02  4.133363e+09  40.828558  1993.530714  1992.415266  ...
# 2024-05-05  3.795748e+09  31.569190  1989.127857  1989.639071  ...
# 2024-05-06  2.891320e+09  30.668681  1984.374286  1984.886906  ...
# 2024-05-07  2.140503e+09  31.845100  1979.907143  1981.182767  ...
# 2024-05-08  2.547031e+09  35.246112  1976.627143  1978.016187  ...
# 2024-05-09  3.121286e+09  41.300191  1974.807143  1976.202928  ...
# 2024-05-12  3.155142e+09  50.873169  1974.975714  1975.940939  ...
# 2024-05-13  3.408608e+09  54.910350  1976.008571  1979.471564  ...
# 2024-05-14  4.088854e+09  68.226862  1980.186429  1986.862092  ...
# 2024-05-15  3.708430e+09  64.366463  1983.672143  1991.647924  ...
# 2024-05-16  4.233816e+09  65.780513  1987.445714  1995.819013  ...
#
#             Inflation Rate(%)  Remittance (in Billons)  Treasury Bill  \
# Date
# 2024-05-02                NaN                      NaN            NaN
# 2024-05-05                NaN                      NaN            NaN
# 2024-05-06                NaN                      NaN            NaN
# 2024-05-07                NaN                      NaN            NaN
# 2024-05-08                NaN                      NaN            NaN
# 2024-05-09                NaN                      NaN            NaN
# 2024-05-12                NaN                      NaN            NaN
# 2024-05-13                NaN                      NaN            NaN
# 2024-05-14                NaN                      NaN            NaN
# 2024-05-15                NaN                      NaN            NaN
# 2024-05-16                NaN                      NaN            NaN
#
#             Commercial Bank rates  CPI  Exchange Rate  Trend  Seasonality  \
# Date
# 2024-05-02                    NaN  NaN         133.54    NaN     1.009906
# 2024-05-05                    NaN  NaN         133.54    NaN     1.013554
# 2024-05-06                    NaN  NaN         133.54    NaN     1.014336
# 2024-05-07                    NaN  NaN         133.54    NaN     1.009803
# 2024-05-08                    NaN  NaN         133.54    NaN     1.013691
# 2024-05-09                    NaN  NaN         133.54    NaN     1.013617
# 2024-05-12                    NaN  NaN         133.54    NaN     1.010411
# 2024-05-13                    NaN  NaN         133.54    NaN     1.002466
# 2024-05-14                    NaN  NaN         133.54    NaN     0.999983
# 2024-05-15                    NaN  NaN         133.54    NaN     0.999657
# 2024-05-16                    NaN  NaN         133.54    NaN     0.996264
#
#             Residue   Target
# Date
# 2024-05-02      NaN  1974.37
# 2024-05-05      NaN  1958.75
# 2024-05-06      NaN  1960.81
# 2024-05-07      NaN  1960.60
# 2024-05-08      NaN  1966.23
# 2024-05-09      NaN  1974.50
# 2024-05-12      NaN  1998.89
# 2024-05-13      NaN  2027.51
# 2024-05-14      NaN  2017.97
# 2024-05-15      NaN  2018.76
# 2024-05-16      NaN      NaN
#
# [11 rows x 25 columns]

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(data['Close'], model='multiplicative',period = 90)
fig = plt.figure()
fig = decomposition.plot()
fig.set_size_inches(20,7)
plt.show()

# %%
merged_data['Trend'] = decomposition.trend
merged_data['Seasonality'] = decomposition.seasonal
merged_data['Residue'] = decomposition.resid
merged_data['Target'] = merged_data['Close'].shift(-1)

# %%
merged_data_1 = merged_data.dropna().copy()
merged_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1763 entries, 2016-07-03 to 2024-03-05
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Open                     1763 non-null   float64
#  1   High                     1763 non-null   float64
#  2   Low                      1763 non-null   float64
#  3   Close                    1763 non-null   float64
#  4   Change                   1763 non-null   float64
#  5   Per Change (%)           1763 non-null   float64
#  6   Turnover                 1763 non-null   float64
#  7   RSI                      1763 non-null   float64
#  8   MA                       1763 non-null   float64
#  9   12-day EMA               1763 non-null   float64
#  10  26-day EMA               1763 non-null   float64
#  11  MACD                     1763 non-null   float64
#  12  ATR                      1763 non-null   float64
#  13  Year                     1763 non-null   int32
#  14  Month                    1763 non-null   int32
#  15  Inflation Rate(%)        1763 non-null   float64
#  16  Remittance (in Billons)  1763 non-null   float64
#  17  Treasury Bill            1763 non-null   float64
#  18  Commercial Bank rates    1763 non-null   float64
#  19  CPI                      1763 non-null   float64
#  20  Exchange Rate            1763 non-null   float64
#  21  Trend                    1763 non-null   float64
#  22  Seasonality              1763 non-null   float64
#  23  Residue                  1763 non-null   float64
#  24  Target                   1763 non-null   float64
# dtypes: float64(23), int32(2)
# memory usage: 344.3 KB

# %%
merged_data_1[predictors].round(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 merged_data_1[predictors].round(2)
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/core/indexes/base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Inflation Rate(%): IR(%)'] not in index"

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model1 = LinearRegression()

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors],train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index = test.index, name = "Predictions")
    combined = pd.concat([test["Target"], preds], axis = 1)
    return combined

# %%
def backtest(data, model, predictors, start=600, step=200):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i]
        test = data.iloc[i:(i+step)]
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    
    return pd.concat(all_predictions)

# %%
predictors = ['Open', 'High', 'Low', 'Turnover', 'RSI', 'MA', 
              'MACD', 'ATR', 'Inflation Rate(%)', 'Remittance (in Billons)', 'Treasury Bill',
              'Commercial Bank rates', 'CPI', 'Exchange Rate','Close', 'Trend', 'Seasonality']

# %%
from sklearn.preprocessing import MinMaxScaler

feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()
merged_data_scaled = feature_scaler.fit_transform(merged_data_1[predictors])
merged_data_scaled = pd.DataFrame(merged_data_scaled, columns = predictors, index = merged_data_1.index)
merged_data_scaled["Target"] = target_scaler.fit_transform(merged_data_1[['Target']])
merged_data_scaled.round(2)
# Out:
#             Open  High   Low  Turnover   RSI    MA  MACD   ATR  \
# Date
# 2016-07-03  0.30  0.29  0.29      0.08  0.85  0.27  0.26  0.14
# 2016-07-04  0.30  0.29  0.30      0.07  0.83  0.28  0.27  0.14
# 2016-07-05  0.29  0.29  0.29      0.05  0.80  0.28  0.28  0.15
# 2016-07-06  0.29  0.29  0.30      0.05  0.79  0.28  0.28  0.14
# 2016-07-10  0.29  0.30  0.30      0.06  0.86  0.29  0.29  0.14
# ...          ...   ...   ...       ...   ...   ...   ...   ...
# 2024-02-28  0.43  0.43  0.43      0.09  0.24  0.46  0.61  0.21
# 2024-02-29  0.43  0.43  0.42      0.12  0.18  0.45  0.63  0.22
# 2024-03-03  0.41  0.41  0.41      0.10  0.18  0.45  0.64  0.23
# 2024-03-04  0.42  0.46  0.42      0.02  0.45  0.45  0.60  0.31
# 2024-03-05  0.47  0.47  0.44      0.19  0.39  0.45  0.60  0.35
#
#             Inflation Rate(%)  Remittance (in Billons)  Treasury Bill  \
# Date
# 2016-07-03               0.99                     0.00           0.00
# 2016-07-04               0.99                     0.00           0.00
# 2016-07-05               0.99                     0.00           0.00
# 2016-07-06               0.99                     0.00           0.00
# 2016-07-10               0.99                     0.00           0.00
# ...                       ...                      ...            ...
# 2024-02-28               0.40                     0.78           0.30
# 2024-02-29               0.40                     0.78           0.30
# 2024-03-03               0.36                     0.88           0.27
# 2024-03-04               0.36                     0.88           0.27
# 2024-03-05               0.36                     0.88           0.27
#
#             Commercial Bank rates   CPI  Exchange Rate  Close  Trend  \
# Date
# 2016-07-03                   0.08  0.00           0.18   0.29   0.29
# 2016-07-04                   0.08  0.00           0.18   0.29   0.29
# 2016-07-05                   0.08  0.00           0.18   0.29   0.29
# 2016-07-06                   0.08  0.00           0.18   0.29   0.29
# 2016-07-10                   0.08  0.00           0.18   0.30   0.29
# ...                           ...   ...            ...    ...    ...
# 2024-02-28                   0.36  0.94           0.98   0.43   0.50
# 2024-02-29                   0.36  0.94           0.98   0.42   0.50
# 2024-03-03                   0.34  0.95           1.00   0.41   0.50
# 2024-03-04                   0.34  0.95           1.00   0.47   0.50
# 2024-03-05                   0.34  0.95           1.00   0.43   0.50
#
#             Seasonality  Target
# Date
# 2016-07-03         0.84    0.29
# 2016-07-04         0.98    0.29
# 2016-07-05         0.98    0.29
# 2016-07-06         0.86    0.30
# 2016-07-10         0.59    0.29
# ...                 ...     ...
# 2024-02-28         0.61    0.42
# 2024-02-29         0.54    0.41
# 2024-03-03         0.63    0.47
# 2024-03-04         0.90    0.43
# 2024-03-05         0.84    0.44
#
# [1763 rows x 18 columns]

# %%
preds = backtest(merged_data_scaled, model1, predictors)
preds[['Target','Predictions']] = target_scaler.inverse_transform(preds[['Target', 'Predictions']])

preds
# Out:
#              Target  Predictions
# Date
# 2019-01-28  1160.99  1161.482048
# 2019-01-29  1160.59  1156.401248
# 2019-01-30  1161.63  1156.107702
# 2019-01-31  1153.06  1157.324593
# 2019-02-03  1144.27  1144.979619
# ...             ...          ...
# 2024-02-28  1972.09  1991.964751
# 2024-02-29  1960.30  1959.742377
# 2024-03-03  2078.00  1954.057825
# 2024-03-04  2007.69  2065.879572
# 2024-03-05  2017.03  1983.668768
#
# [1163 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse = mean_squared_error(preds['Target'], preds['Predictions'])
rmse = sqrt(mse)

# %%
rmse
# Out:
# 30.757118328807852

# %%
sorted(zip(model1.coef_, predictors), reverse = True)
# Out:
# [(1.3083038831146199, 'Close'),
#  (0.15575966090891258, 'Open'),
#  (0.11049016371281696, 'Trend'),
#  (0.009061737754021415, 'Turnover'),
#  (0.0053226001317680065, 'Treasury Bill'),
#  (0.0037178991521298384, 'Inflation Rate(%)'),
#  (0.0031047114705010617, 'RSI'),
#  (-0.0012392236581253496, 'ATR'),
#  (-0.0014115529890449978, 'Remittance (in Billons)'),
#  (-0.0020481855049476806, 'Seasonality'),
#  (-0.0023122671159394453, 'Exchange Rate'),
#  (-0.002491612886695683, 'Commercial Bank rates'),
#  (-0.004310971739402429, 'CPI'),
#  (-0.015800349666674388, 'MACD'),
#  (-0.02323413031271165, 'MA'),
#  (-0.21136944158539156, 'Low'),
#  (-0.35796659586393775, 'High')]

# %%
preds.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Without Backtesting

# %%
X_train = merged_data_scaled[predictors][:1400]
y_train = merged_data_scaled['Target'][:1400]
X_test = merged_data_scaled[predictors][1400:]
y_test = merged_data_scaled['Target'][1400:]
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1400, 17), (363, 17), (1400,), (363,))

# %%
model1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
preds_no_back_testing = model1.predict(X_test)
y_test = y_test[y_test.isnull() == False]

# %%
mse = mean_squared_error(y_test, preds_no_back_testing)
mse
# Out:
# 0.0001455087163615976

# %%
preds_no_back_testing = pd.Series(preds_no_back_testing , index = X_test.index, name = 'Predictions')
result = pd.concat([y_test, preds_no_back_testing ], axis = 1)
result.head()
# Out:
#               Target  Predictions
# Date
# 2022-08-07  0.479295     0.484352
# 2022-08-08  0.458632     0.473137
# 2022-08-09  0.455811     0.452791
# 2022-08-10  0.446774     0.452416
# 2022-08-11  0.433471     0.440163

# %%
result.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
model_random_forest = RandomForestRegressor(n_estimators = 200, min_samples_split = 50, random_state = 47)

# %%
preds_rf = backtest( merged_data_scaled,model_random_forest, predictors)
preds_rf = preds_rf.dropna()

# %%
mse_1 = mean_squared_error(preds_rf['Target'], preds_rf['Predictions'])
mse_1
# Out:
# 0.023120623307200654

# %%
preds_rf.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
def create_sequences(data, window_size=5):
    sequences = []
    targets = []
    for i in range(len(data) - window_size):
        sequences.append(data.iloc[i:i + window_size, :-1].values)  # Exclude last column (Target) for X
        targets.append(data.iloc[i + window_size, -1])  # Last column (Target) for y
    return np.array(sequences), np.array(targets)

# %%
window_size = 5
lstm_data_scaled = feature_scaler.fit_transform(merged_data_1[predictors])
target_scaled = target_scaler.fit_transform(merged_data_1[['Target']])
lstm_data = np.concatenate((lstm_data_scaled, target_scaled), axis=1)

# %%
X, y = create_sequences(pd.DataFrame(lstm_data, columns = predictors + ['Target']), window_size)

# %%
train_size = int(0.7 * len(X))
val_size = int(0.1 * len(X))
test_size = len(X) - train_size - val_size

X_train, X_val, X_test = X[:train_size], X[train_size:train_size + val_size], X[train_size + val_size:]
y_train, y_val, y_test = y[:train_size], y[train_size:train_size + val_size], y[train_size + val_size:]
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape

# %%
model = Sequential()
model.add(Input(shape = (window_size, X_train.shape[2])))
model.add(LSTM(30))
model.add(Dense(1, activation = "linear"))

# %%
model.summary()

# %%
model.compile(optimizer = Adam(learning_rate = 0.1), loss = MeanSquaredError(), metrics = [RootMeanSquaredError()])

# %%
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_val, y_val))

# %%
# Make predictions
predictions_scaled = model.predict(X_test)
predictions_scaled

# %%
preds = pd.DataFrame({
    'Target': y_test,
    'Predictions': predictions_scaled.flatten()
})

preds[['Target', 'Predictions']] = target_scaler.inverse_transform(preds[['Target', 'Predictions']])
preds

# %%
rmse = sqrt(mean_squared_error(preds['Target'], preds['Predictions']))
rmse
